# %% [markdown]
# # EDA and data preparation
# *@XavierTorres*

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.max_open_warning'] = 0
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('OUTPUT_WBI_cyclones_merged.csv', sep = ';')

# %%
df = pd.read_csv('../../#task1-datacollection/datasets/OUTPUT_WBI_exposer_cyclones.csv')

# %%
df
# Out:
#       Unnamed: 0    ID           NAME  ISO  Year  \
# 0              0     1          DELLA  JPN  1949
# 1              1     2           JANE  JPN  1950
# 2              2     3        CHARLIE  JAM  1951
# 3              3     4            AMY  PHL  1951
# 4              4     5           EMMA  PHL  1952
# 5              5     6          HAZEL  HTI  1954
# 6              6     7          HILDA  MEX  1955
# 7              7     8           VERA  JPN  1959
# 8              8     9          OLIVE  PHL  1960
# 9              9    10            KIT  PHL  1960
# 10            10    11         CARMEN  PHL  1963
# 11            11    12           CLEO  HTI  1964
# 12            12    13           IRIS  VNM  1964
# 13            13    14          DINAH  JPN  1965
# 14            14    15          DINAH  TWN  1965
# 15            15    16           MARY  TWN  1965
# 16            16    17        SHIRLEY  JPN  1965
# 17            17    18           JUDY  TWN  1966
# 18            18    19           INEZ  CUB  1966
# 19            19    20           INEZ  DOM  1966
# 20            20    21           INEZ  MEX  1966
# 21            21    22         ANGELA  SLB  1966
# 22            22    23         BILLIE  JPN  1967
# 23            23    24         BEULAH  USA  1967
# 24            24    25      GEORGETTE  MDG  1968
# 25            25    26          BECKY  SLB  1968
# 26            26    27           DANY  MDG  1969
# 27            27    28      FRANCELIA  GTM  1969
# 28            28    29           JANE  MDG  1970
# 29            29    32           FRAN  CHN  1970
# ...          ...   ...            ...  ...   ...
# 1044        1044  1061           KENI  FJI  2018
# 1045        1045  1062         MEKUNU  YEM  2018
# 1046        1046  1063        ALBERTO  CUB  2018
# 1047        1047  1064          MARIA  CHN  2018
# 1048        1048  1065       SON-TINH  LAO  2018
# 1049        1049  1066       SON-TINH  PHL  2018
# 1050        1050  1068       SON-TINH  VNM  2018
# 1051        1051  1069          AMPIL  CHN  2018
# 1052        1052  1070           YAGI  CHN  2018
# 1053        1053  1071        BEBINCA  VNM  2018
# 1054        1054  1072       MANGKHUT  PHL  2018
# 1055        1055  1073         LESLIE  PRT  2018
# 1056        1056  1074        MICHAEL  CUB  2018
# 1057        1057  1075          LUBAN  YEM  2018
# 1058        1058  1076          TITLI  IND  2018
# 1059        1059  1077           YUTU  PHL  2018
# 1060        1060  1078           IDAI  MDG  2019
# 1061        1061  1079           IDAI  MOZ  2019
# 1062        1062  1080        KENNETH  COM  2019
# 1063        1063  1081           FANI  IND  2019
# 1064        1064  1082   LOUISE:MARGE  PHL  1964
# 1065        1065  1083       IVY:JEAN  JPN  1965
# 1066        1066  1084  FLOSSIE:GRACE  TWN  1969
# 1067        1067  1085    FIFI:ORLENE  BLZ  1974
# 1068        1068  1086    FIFI:ORLENE  HND  1974
# 1069        1069  1087        BRENDAN  KOR  1985
# 1070        1070  1088    JOAN:MIRIAM  COL  1988
# 1071        1071  1089    JOAN:MIRIAM  NIC  1988
# 1072        1072  1090    JOAN:MIRIAM  PAN  1988
# 1073        1073  1091            NaN  PHL  1988
#
#                                                  COORDS BASIN SUBBASIN NATURE  \
# 0     [[31.99, 130.68], [33.52, 130.97], [41.0, 140....    WP       WP     ET
# 1     [[34.94, 135.48], [36.1, 136.09], [37.27, 136....    WP       WP     TS
# 2                        [[17.9, -76.9], [18.1, -77.8]]   NAm      NAm     TS
# 3     [[10.73, 124.8], [10.53, 123.17], [10.68, 119....    WP       WP     TS
# 4     [[10.47, 123.87], [10.65, 123.24], [10.83, 122...    WP       WP     TS
# 5     [[18.3, -74.2], [18.6, -74.0], [19.6, -73.4], ...   NAm      NAm     TS
# 6     [[19.7, -87.7], [19.75, -87.87], [19.9, -88.4]...   NAm      NAm     TS
# 7     [[33.63, 135.69], [35.2, 136.47], [36.89, 137....    WP       WP     TS
# 8     [[13.57, 124.17], [13.73, 123.61], [13.9, 123....    WP       WP     TS
# 9     [[12.86, 124.04], [12.9, 123.63], [13.13, 121....    WP       WP     TS
# 10    [[13.73, 124.31], [15.92, 121.6], [16.2, 121.0...    WP       WP     TS
# 11                                    [[18.12, -73.87]]   NAm      NAm     TS
# 12    [[13.63, 109.08], [13.65, 108.66], [13.66, 108...    WP       WP     TS
# 13    [[33.5, 131.55], [34.63, 132.78], [36.68, 136....    WP       WP     MX
# 14    [[22.98, 121.0], [23.62, 120.96], [24.49, 121....    WP       WP     TS
# 15    [[24.55, 121.72], [24.61, 121.43], [24.69, 121...    WP       WP     TS
# 16    [[33.79, 134.24], [35.3, 135.18], [43.21, 140....    WP       WP     TS
# 17                    [[22.79, 120.57], [22.89, 121.2]]    WP       WP     TS
# 18    [[20.01, -75.86], [20.2, -76.3], [20.36, -76.6...   NAm      NAm     TS
# 19                                    [[17.76, -71.59]]   NAm      NAm     TS
# 20    [[22.8, -97.8], [22.61, -98.15], [22.4, -98.5]...   NAm      NAm     TS
# 21    [[-8.6, 161.03], [-8.97, 160.89], [-9.57, 160....    SP       SP     TS
# 22    [[34.0, 130.9], [34.69, 132.99], [35.15, 135.1...    WP       WP     ET
# 23    [[25.9, -97.2], [26.14, -97.45], [26.4, -97.7]...   NAm      NAm     TS
# 24    [[-13.4, 49.82], [-13.38, 49.41], [-13.39, 48....    SI       SI     MX
# 25    [[-9.28, 161.28], [-9.42, 161.16], [-9.92, 160...    SP       SP     TS
# 26    [[-20.1, 48.58], [-20.13, 48.19], [-20.2, 47.7...    SI       SI     TS
# 27                     [[16.1, -89.2], [16.14, -89.44]]   NAm       CS     TS
# 28    [[-20.46, 48.38], [-20.72, 48.02], [-20.94, 47...    SI       SI     TS
# 29    [[25.04, 118.9], [25.11, 118.55], [25.14, 118....    WP       WP     TS
# ...                                                 ...   ...      ...    ...
# 1044  [[-18.7, 177.0], [-19.05, 178.11], [-18.22, 17...    SP       MM     NR
# 1045  [[12.0, 56.0], [12.31, 55.89], [12.6, 55.8], [...    NI       AS     NR
# 1046  [[21.92, -85.12], [22.8, -85.2], [20.9, -85.07...   NAm       GM     SS
# 1047  [[26.4, 120.1], [26.5, 119.16], [26.61, 118.31...    WP       MM     NR
# 1048  [[19.43, 103.68], [19.5, 103.28], [19.6, 103.0...    WP       MM     NR
# 1049  [[18.71, 123.08], [18.7, 122.2], [18.87, 121.7...    WP       MM     NR
# 1050  [[18.8, 106.7], [18.82, 106.13], [18.9, 105.6]...    WP       MM     NR
# 1051  [[31.23, 122.48], [31.9, 122.1], [32.34, 121.6...    WP       MM     NR
# 1052                   [[28.15, 121.61], [27.5, 122.5]]    WP       MM     NR
# 1053  [[20.1, 107.6], [20.06, 107.44], [20.0, 107.3]...    WP       MM     NR
# 1054  [[17.74, 123.22], [18.0, 122.3], [18.07, 121.3...    WP       MM     NR
# 1055                     [[40.24, -9.0], [39.3, -10.5]]   NAm      NAm     ET
# 1056  [[21.28, -85.06], [21.7, -85.1], [22.19, -85.1...   NAm       GM     TS
# 1057  [[15.5, 52.8], [15.68, 52.42], [15.0, 53.7], [...    NI       AS     NR
# 1058  [[18.5, 85.2], [18.76, 84.9], [17.29, 85.53], ...    NI       BB     NR
# 1059  [[16.8, 123.0], [16.84, 122.26], [16.86, 121.4...    WP       MM     NR
# 1060  [[-17.18, 43.14], [-17.2, 43.2], [-17.25, 43.2...    SI       MM     NR
# 1061  [[-17.0, 40.2], [-17.17, 40.78], [-17.2, 41.3]...    SI       MM     NR
# 1062                   [[-11.42, 42.28], [-11.6, 41.8]]    SI       MM     NR
# 1063  [[17.96, 84.86], [18.3, 85.0], [18.61, 85.24],...    NI       BB     NR
# 1064  [[9.07, 127.13], [9.3, 126.66], [9.51, 126.19]...    WP       MM     TS
# 1065  [[31.24, 129.56], [31.95, 129.96], [32.74, 130...    WP       MM     TS
# 1066  [[21.94, 121.81], [22.27, 121.7], [22.57, 121....    WP       MM     TS
# 1067                   [[16.3, -88.2], [16.51, -88.65]]   NAm       CS     TS
# 1068  [[16.3, -83.5], [16.31, -84.11], [16.3, -84.7]...   NAm       CS     TS
# 1069  [[33.04, 127.24], [33.94, 128.19], [34.59, 129...    WP       MM     TS
# 1070  [[11.96, -71.66], [11.9, -72.1], [11.84, -72.5...   NAm       CS     TS
# 1071  [[11.91, -82.85], [11.9, -83.2], [11.9, -83.58...    EP       CS     TS
# 1072  [[11.2, -79.6], [11.1, -79.8], [11.07, -79.66]...   NAm       CS     TS
# 1073  [[12.27, 125.57], [11.85, 124.75], [11.5, 124....    WP       MM     NR
#
#                                                ISO_TIME  ...  \
# 0     ['1949-06-20 15:00:00', '1949-06-20 18:00:00',...  ...
# 1     ['1950-09-03 03:00:00', '1950-09-03 06:00:00',...  ...
# 2        ['1951-08-18 03:00:00', '1951-08-18 06:00:00']  ...
# 3     ['1951-12-09 12:00:00', '1951-12-09 21:00:00',...  ...
# 4     ['1952-07-02 12:00:00', '1952-07-02 15:00:00',...  ...
# 5     ['1954-10-12 09:00:00', '1954-10-12 12:00:00',...  ...
# 6     ['1955-09-16 14:00:00', '1955-09-16 15:00:00',...  ...
# 7     ['1959-09-26 09:00:00', '1959-09-26 12:00:00',...  ...
# 8     ['1960-06-25 18:00:00', '1960-06-25 21:00:00',...  ...
# 9     ['1960-10-06 09:00:00', '1960-10-06 12:00:00',...  ...
# 10    ['1963-08-13 00:00:00', '1963-08-13 21:00:00',...  ...
# 11                              ['1964-08-24 21:00:00']  ...
# 12    ['1964-11-04 06:00:00', '1964-11-04 09:00:00',...  ...
# 13    ['1965-06-20 00:00:00', '1965-06-20 03:00:00',...  ...
# 14    ['1965-06-18 15:00:00', '1965-06-18 18:00:00',...  ...
# 15    ['1965-08-18 18:00:00', '1965-08-18 21:00:00',...  ...
# 16    ['1965-09-10 00:00:00', '1965-09-10 03:00:00',...  ...
# 17       ['1966-05-30 12:00:00', '1966-05-30 15:00:00']  ...
# 18    ['1966-09-30 15:00:00', '1966-09-30 18:00:00',...  ...
# 19                              ['1966-09-29 15:00:00']  ...
# 20    ['1966-10-10 12:00:00', '1966-10-10 15:00:00',...  ...
# 21    ['1966-11-13 23:00:00', '1966-11-14 02:00:00',...  ...
# 22    ['1967-07-09 06:00:00', '1967-07-09 09:00:00',...  ...
# 23    ['1967-09-20 12:00:00', '1967-09-20 15:00:00',...  ...
# 24    ['1968-01-15 09:00:00', '1968-01-15 12:00:00',...  ...
# 25    ['1968-12-11 03:00:00', '1968-12-11 06:00:00',...  ...
# 26    ['1969-02-04 06:00:00', '1969-02-04 09:00:00',...  ...
# 27       ['1969-09-04 06:00:00', '1969-09-04 09:00:00']  ...
# 28    ['1970-02-23 03:00:00', '1970-02-23 06:00:00',...  ...
# 29    ['1970-09-07 18:00:00', '1970-09-07 21:00:00',...  ...
# ...                                                 ...  ...
# 1044  ['2018-04-10 00:00:00', '2018-04-10 03:00:00',...  ...
# 1045  ['2018-05-23 12:00:00', '2018-05-23 15:00:00',...  ...
# 1046  ['2018-05-26 15:00:00', '2018-05-26 18:00:00',...  ...
# 1047  ['2018-07-11 00:00:00', '2018-07-11 03:00:00',...  ...
# 1048  ['2018-07-19 06:00:00', '2018-07-19 09:00:00',...  ...
# 1049  ['2018-07-16 09:00:00', '2018-07-16 12:00:00',...  ...
# 1050  ['2018-07-18 12:00:00', '2018-07-18 15:00:00',...  ...
# 1051  ['2018-07-22 03:00:00', '2018-07-22 06:00:00',...  ...
# 1052     ['2018-08-12 15:00:00', '2018-08-12 12:00:00']  ...
# 1053  ['2018-08-16 06:00:00', '2018-08-16 09:00:00',...  ...
# 1054  ['2018-09-14 15:00:00', '2018-09-14 18:00:00',...  ...
# 1055     ['2018-10-13 21:00:00', '2018-10-13 18:00:00']  ...
# 1056  ['2018-10-08 15:00:00', '2018-10-08 18:00:00',...  ...
# 1057  ['2018-10-14 00:00:00', '2018-10-14 03:00:00',...  ...
# 1058  ['2018-10-10 18:00:00', '2018-10-10 21:00:00',...  ...
# 1059  ['2018-10-29 18:00:00', '2018-10-29 21:00:00',...  ...
# 1060  ['2019-03-10 15:00:00', '2019-03-10 18:00:00',...  ...
# 1061  ['2019-03-09 06:00:00', '2019-03-09 09:00:00',...  ...
# 1062     ['2019-04-25 03:00:00', '2019-04-25 06:00:00']  ...
# 1063  ['2019-05-02 15:00:00', '2019-05-02 18:00:00',...  ...
# 1064  ['1964-11-18 18:00:00', '1964-11-18 21:00:00',...  ...
# 1065  ['1965-08-05 15:00:00', '1965-08-05 18:00:00',...  ...
# 1066  ['1969-10-02 03:00:00', '1969-10-02 06:00:00',...  ...
# 1067     ['1974-09-19 18:00:00', '1974-09-19 21:00:00']  ...
# 1068  ['1974-09-18 12:00:00', '1974-09-18 15:00:00',...  ...
# 1069  ['1985-10-05 03:00:00', '1985-10-05 06:00:00',...  ...
# 1070  ['1988-10-17 09:00:00', '1988-10-17 12:00:00',...  ...
# 1071  ['1988-10-22 03:00:00', '1988-10-22 06:00:00',...  ...
# 1072  ['1988-10-20 03:00:00', '1988-10-20 06:00:00',...  ...
# 1073  ['1988-11-01 18:00:00', '1988-11-01 21:00:00',...  ...
#
#       Mobile cellular subscriptions (per 100 people)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                           0.000000
# 9                                           0.000000
# 10                                          0.000000
# 11                                          0.000000
# 12                                          0.000000
# 13                                          0.000000
# 14                                          0.000000
# 15                                          0.000000
# 16                                          0.000000
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000000
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                          0.000000
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
# 27                                          0.000000
# 28                                          0.000000
# 29                                          0.000000
# ...                                              ...
# 1044                                      113.748754
# 1045                                       53.678933
# 1046                                       47.391537
# 1047                                      115.525812
# 1048                                       51.863377
# 1049                                      126.198639
# 1050                                      147.195273
# 1051                                      115.525812
# 1052                                      115.525812
# 1053                                      147.195273
# 1054                                      126.198639
# 1055                                      115.633042
# 1056                                       47.391537
# 1057                                       53.678933
# 1058                                       86.942563
# 1059                                      126.198639
# 1060                                       35.712976
# 1061                                       51.655359
# 1062                                       57.220464
# 1063                                       84.790274
# 1064                                        0.000000
# 1065                                        0.000000
# 1066                                        0.000000
# 1067                                        0.000000
# 1068                                        0.000000
# 1069                                        0.000000
# 1070                                        0.000000
# 1071                                        0.000000
# 1072                                        0.000000
# 1073                                        0.000000
#
#       Population density (people per sq. km of land area)  \
# 0                                            258.911917
# 1                                            258.911917
# 2                                            152.453647
# 3                                             91.065000
# 4                                             91.065000
# 5                                            143.031350
# 6                                             20.044783
# 7                                            258.911917
# 8                                             91.065000
# 9                                             91.065000
# 10                                            97.272933
# 11                                           151.583345
# 12                                           112.998860
# 13                                           269.656395
# 14                                            76.178734
# 15                                            76.178734
# 16                                           269.656395
# 17                                            78.331958
# 18                                            75.563194
# 19                                            82.794370
# 20                                            23.416105
# 21                                             5.037192
# 22                                           274.679575
# 23                                            21.695913
# 24                                            10.720613
# 25                                             5.354805
# 26                                            11.008565
# 27                                            51.003285
# 28                                            11.308431
# 29                                            87.163742
# ...                                                 ...
# 1044                                          48.357033
# 1045                                          53.977853
# 1046                                         108.999596
# 1047                                         148.348833
# 1048                                          30.595784
# 1049                                         357.688305
# 1050                                         308.125246
# 1051                                         148.348833
# 1052                                         148.348833
# 1053                                         308.125246
# 1054                                         357.688305
# 1055                                         112.239453
# 1056                                         108.999596
# 1057                                          53.977853
# 1058                                         454.938073
# 1059                                         357.688305
# 1060                                          43.326343
# 1061                                          35.876238
# 1062                                         432.007513
# 1063                                         447.629810
# 1064                                         100.444874
# 1065                                         269.656395
# 1066                                          84.789498
# 1067                                           5.756554
# 1068                                          27.341487
# 1069                                         423.032801
# 1070                                          28.681861
# 1071                                          33.202036
# 1072                                          31.861057
# 1073                                         197.186172
#
#       Adjusted savings: education expenditure (% of GNI)  \
# 0                                              2.867878
# 1                                              2.867878
# 2                                              2.578304
# 3                                              2.757732
# 4                                              2.757732
# 5                                              1.284442
# 6                                              3.003239
# 7                                              2.867878
# 8                                              2.757732
# 9                                              2.757732
# 10                                             2.757732
# 11                                             1.284442
# 12                                             2.300000
# 13                                             2.867878
# 14                                             1.610277
# 15                                             1.610277
# 16                                             2.867878
# 17                                             1.610277
# 18                                             6.445202
# 19                                             2.500000
# 20                                             3.003239
# 21                                             4.100000
# 22                                             2.867878
# 23                                             7.454724
# 24                                             2.800000
# 25                                             4.100000
# 26                                             2.800000
# 27                                             1.700000
# 28                                             2.800000
# 29                                             1.610277
# ...                                                 ...
# 1044                                           3.955082
# 1045                                           3.600000
# 1046                                          13.010000
# 1047                                           1.790000
# 1048                                           2.618630
# 1049                                           1.840000
# 1050                                           4.603050
# 1051                                           1.790000
# 1052                                           1.790000
# 1053                                           4.603050
# 1054                                           1.840000
# 1055                                           4.816790
# 1056                                          13.010000
# 1057                                           3.600000
# 1058                                           3.080000
# 1059                                           1.840000
# 1060                                           2.080000
# 1061                                           5.380000
# 1062                                           4.326607
# 1063                                           3.080000
# 1064                                           2.757732
# 1065                                           2.867878
# 1066                                           1.610277
# 1067                                           4.182590
# 1068                                           2.939081
# 1069                                           3.400000
# 1070                                           2.600000
# 1071                                           3.700000
# 1072                                           4.900000
# 1073                                           2.000000
#
#       Rural population (% of total population)  Income_level_Final  \
# 0                                    36.728000                 Low
# 1                                    36.728000                 Low
# 2                                    66.231000                 Low
# 3                                    69.703000          Low_Middle
# 4                                    69.703000          Low_Middle
# 5                                    84.407000          Low_Middle
# 6                                    49.247000                 Low
# 7                                    36.728000                 Low
# 8                                    69.703000          Low_Middle
# 9                                    69.703000          Low_Middle
# 10                                   68.923000          Low_Middle
# 11                                   82.832000          Low_Middle
# 12                                   83.936000                 Low
# 13                                   32.134000                 Low
# 14                                   81.914000          Low_Middle
# 15                                   81.914000          Low_Middle
# 16                                   32.134000                 Low
# 17                                   82.085000          Low_Middle
# 18                                   40.477000          Low_Middle
# 19                                   63.927000          Low_Middle
# 20                                   44.239000                 Low
# 21                                   92.421000          Low_Middle
# 22                                   30.484000                High
# 23                                   27.388000                High
# 24                                   86.590000          Low_Middle
# 25                                   91.708000          Low_Middle
# 26                                   86.249000          Low_Middle
# 27                                   64.768000          Low_Middle
# 28                                   85.900000          Low_Middle
# 29                                   82.600000          Low_Middle
# ...                                        ...                 ...
# 1044                                 43.752000         High_Middle
# 1045                                 63.358000                 Low
# 1046                                 22.963000         High_Middle
# 1047                                 40.848000         High_Middle
# 1048                                 64.996000          Low_Middle
# 1049                                 53.093000          Low_Middle
# 1050                                 64.081000          Low_Middle
# 1051                                 40.848000         High_Middle
# 1052                                 40.848000         High_Middle
# 1053                                 64.081000          Low_Middle
# 1054                                 53.093000          Low_Middle
# 1055                                 34.789000                High
# 1056                                 22.963000         High_Middle
# 1057                                 63.358000                 Low
# 1058                                 65.970000          Low_Middle
# 1059                                 53.093000          Low_Middle
# 1060                                 63.839788                 Low
# 1061                                 64.832034                 Low
# 1062                                 71.300771          Low_Middle
# 1063                                 66.623697          Low_Middle
# 1064                                 68.660000          Low_Middle
# 1065                                 32.134000                 Low
# 1066                                 82.472000          Low_Middle
# 1067                                 49.671000          Low_Middle
# 1068                                 68.429000          Low_Middle
# 1069                                 35.124000                 Low
# 1070                                 31.468000                 Low
# 1071                                 47.481000                 Low
# 1072                                 46.841000         High_Middle
# 1073                                 54.817000          Low_Middle
#
#       Total Affected    pop_max_34    pop_max_50    pop_max_64  Numeric
# 0             194046  2.823009e+07  4.378624e+06  7.321548e+05    392.0
# 1             642117  6.207195e+07  1.455101e+07  4.093306e+06    392.0
# 2              20200  2.753688e+06  2.606976e+06  1.067878e+06    388.0
# 3              60000  2.228376e+07  8.444818e+06  1.750716e+06    608.0
# 4                103  3.670926e+07  7.952954e+06  4.470182e+06    608.0
# 5             250000  9.843221e+06  1.411192e+06  5.954847e+05    332.0
# 6              11432  2.720307e+07  1.973763e+06  1.474285e+06    484.0
# 7            1500000  8.082860e+07  6.812950e+06  1.247277e+06    392.0
# 8              50000  5.464183e+07  2.877023e+07  8.354356e+06    608.0
# 9             375000  5.605068e+07  3.270401e+06  1.389018e+06    608.0
# 10              2000  5.518282e+07  4.103970e+06  1.316760e+06    608.0
# 11             80000  9.843221e+06  1.074516e+06  3.856841e+05    332.0
# 12            700000  2.225939e+07  2.619435e+06  1.120947e+06    704.0
# 13             30000  1.130948e+08  6.919552e+06  1.589897e+06    392.0
# 14                89  2.018165e+07  7.228424e+06  3.385504e+05    158.0
# 15                77  2.016036e+07  7.856623e+06  1.709735e+06    158.0
# 16               730  5.932739e+07  2.166733e+06  3.187589e+05    392.0
# 17              5021  2.018165e+07  3.347583e+06  9.572899e+05    158.0
# 18            174030  1.104471e+07  3.672081e+06  2.006602e+06    192.0
# 19             12942  1.034940e+07  6.188423e+04  9.543681e+03    214.0
# 20             90069  3.738504e+07  1.397659e+06  4.707823e+05    484.0
# 21              1000           NaN           NaN           NaN      NaN
# 22              3005  1.128200e+08  1.051949e+07  2.159304e+06    392.0
# 23             30000  5.534590e+06  1.439478e+06  3.990791e+05    840.0
# 24             75000  7.065562e+06  1.106430e+06  5.039272e+05    450.0
# 25               200           NaN           NaN           NaN      NaN
# 26             43040  1.430134e+07  1.595394e+06  6.977634e+05    450.0
# 27             10200  1.276484e+07  2.347976e+05  3.382391e+04    320.0
# 28             10000  1.664736e+07  4.502799e+06  2.318576e+06    450.0
# 29             14000  2.077470e+08  3.057151e+07  1.341463e+07    156.0
# ...              ...           ...           ...           ...      ...
# 1044           89250  7.223178e+05  7.511531e+03  0.000000e+00    242.0
# 1045             750  9.955565e+04  0.000000e+00  0.000000e+00    887.0
# 1046           40000  2.326496e+06  1.288722e+04  0.000000e+00    192.0
# 1047           45000  1.090726e+08  4.391347e+05  3.397131e+05    156.0
# 1048          120000  2.148101e+06  4.383626e+05  3.147044e+05    418.0
# 1049         2231101  2.373122e+06  1.092894e+04  5.440023e+02    608.0
# 1050           96000  3.833158e+07  1.985339e+07  1.561710e+07    704.0
# 1051           18000  2.111278e+08  1.682919e+07  9.423004e+06    156.0
# 1052            2400  1.639067e+07  0.000000e+00  0.000000e+00    156.0
# 1053           50000  2.430393e+07  0.000000e+00  0.000000e+00    704.0
# 1054         3800138  5.263017e+07  2.173110e+06  1.905628e+07    608.0
# 1055              88  5.278070e+06  1.406338e+06  0.000000e+00    620.0
# 1056             540  1.633107e+06  8.993927e+04  4.874504e+03    192.0
# 1057           15124  5.151528e+04  0.000000e+00  0.000000e+00    887.0
# 1058          300200  3.205416e+07  0.000000e+00  0.000000e+00    356.0
# 1059          253300  4.844936e+07  4.642600e+06  8.813562e+05    608.0
# 1060            1100  2.402440e+05  0.000000e+00  0.000000e+00    450.0
# 1061         1501500  2.036736e+06  0.000000e+00  0.000000e+00    508.0
# 1062          345311           NaN           NaN           NaN      NaN
# 1063        20000000  6.208134e+07  1.539366e+03  0.000000e+00    356.0
# 1064          301258  7.866882e+07  1.427121e+07  5.675014e+06    608.0
# 1065              40  2.177560e+07  4.306329e+06  1.051040e+06    392.0
# 1066           40408  2.018165e+07  0.000000e+00  0.000000e+00    158.0
# 1067           70000  3.498301e+05  8.755287e+04  2.869141e+04     84.0
# 1068          600000  7.433512e+06  5.010369e+05  2.949578e-02    340.0
# 1069              20  1.573929e+07  1.346350e+07  0.000000e+00    410.0
# 1070          100000  8.269079e+06  3.800307e+05  1.725153e+05    170.0
# 1071          360278  5.965988e+06  2.778494e+06  1.989748e+06    558.0
# 1072            8732  2.419037e+06  0.000000e+00  0.000000e+00    591.0
# 1073           28913           NaN           NaN           NaN      NaN
#
# [1074 rows x 44 columns]

# %% [markdown]
# ### Changes into data values (read documentation link)
# https://docs.google.com/spreadsheets/d/1ff0m-Tl1QrNvR_zQ_WRleuRZevta-JBdXVVDsfLTwOQ/edit#gid=0

# %% [markdown]
# BASIN and SUBBASIN: 'MM' value means missing:

# %%
df["SUBBASIN"]= df["SUBBASIN"].replace('MM', df["BASIN"]) 
df["BASIN"]= df["BASIN"].replace('MM', df["SUBBASIN"])

# %%
df['SUBBASIN']= np.where(df['SUBBASIN'].isnull(), df['BASIN'], df['SUBBASIN'])

# %% [markdown]
# USA_SSHS column with value -5 = Unknown [XX]:

# %%
df["USA_SSHS"]= df["USA_SSHS"].replace(-5, np.nan)

# %% [markdown]
# As damage in '000 USD is time-money sensitive, we can use the CPI for that data point to calculate "Total Damage Adjusted"
# by dividing Total Damage by the CPI. We then drop columns for Damage and CPI.
# CPI meaning = https://en.wikipedia.org/wiki/Consumer_price_index

# %%
df["Total damage ('000$)_Adjusted"]= df["Total damage ('000$)"] / df["CPI"]
df["Total damage ('000$)_Adjusted"]= df["Total damage ('000$)_Adjusted"].replace(0, np.nan)

# %%
df = df.drop(["Total damage ('000$)",'CPI'], axis=1)
df["Total damage ('000$)_Adjusted"].isna().sum()
# Out:
# 335

# %% [markdown]
# Trying to create a calculated column that better represents de relative dimension of exposed population and assets. We have several columns for people and assets exposed depending of windspeed (v_land_kn) for 34kn+, 64kn+ and 96kn+. Let's add these columns to createa new column:

# %%
df['CALC_pop_exposed'] = df['34kn_pop'] + df['64kn_pop'] + df['96kn_pop']

# %% [markdown]
# Let's do the same for asset exposure

# %%
df['CALC_assets_exposed'] = df['34kn_assets'] + df['64kn_assets'] + df['96kn_assets']

# %%
df.sample(2)
# Out:
#      Unnamed: 0   ID      NAME  ISO  Year  \
# 812         812  828  MINDULLE  PHL  2004
# 51           51   54      IRMA  JPN  1978
#
#                                                 COORDS BASIN SUBBASIN NATURE  \
# 812  [[18.9, 123.03], [18.95, 122.82], [19.0, 122.6...    WP       WP     TS
# 51   [[34.35, 131.86], [34.64, 133.01], [34.88, 134...    WP       WP     TS
#
#                                               ISO_TIME  ...  \
# 812  ['2004-06-29 12:00:00', '2004-06-29 15:00:00',...  ...
# 51   ['1978-09-15 09:00:00', '1978-09-15 12:00:00',...  ...
#
#      Rural population (% of total population)  Income_level_Final  \
# 812                                    54.205          Low_Middle
# 51                                     23.940                High
#
#      Total Affected  pop_max_34    pop_max_50    pop_max_64  Numeric  \
# 812          385012   4251474.5  1.746245e+06  1.304274e+04    608.0
# 51             3100  59580844.0  3.177930e+07  2.900005e+06    392.0
#
#      Total damage ('000$)_Adjusted  CALC_pop_exposed  CALC_assets_exposed
# 812                      266.19686         6244569.0         3.714542e+10
# 51                             NaN        18292306.0         2.380000e+12
#
# [2 rows x 45 columns]

# %%
df = df.drop(['34kn_pop', '34kn_assets', '64kn_pop', '64kn_assets', '96kn_pop','96kn_assets','Unnamed: 0'], axis=1)

# %% [markdown]
# Let's arrange columns of dataframe:

# %%
df.columns
# Out:
# Index(['ID', 'NAME', 'ISO', 'Year', 'COORDS', 'BASIN', 'SUBBASIN', 'NATURE',
#        'ISO_TIME', 'TOTAL_HRS', 'DAY_HRS', 'NIGHT_HRS', 'USA_SSHS',
#        'PRES_CALC_mean', 'STORM_SPD_mean', 'STORM_DR_mean', 'v_land_kn',
#        'Air transport, freight (million ton-km)',
#        'Arable land (hectares per person)', 'Cereal yield (kg per hectare)',
#        'Food production index (2004-2006 = 100)', 'GDP growth (annual %)',
#        'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$',
#        'Life expectancy at birth, total (years)',
#        'Mobile cellular subscriptions (per 100 people)',
#        'Population density (people per sq. km of land area)',
#        'Adjusted savings: education expenditure (% of GNI)',
#        'Rural population (% of total population)', 'Income_level_Final',
#        'Total Affected', 'pop_max_34', 'pop_max_50', 'pop_max_64', 'Numeric',
#        'Total damage ('000$)_Adjusted', 'CALC_pop_exposed',
#        'CALC_assets_exposed'],
#       dtype='object')

# %%
df['pop_max_64']
# Out:
# 0       7.321548e+05
# 1       4.093306e+06
# 2       1.067878e+06
# 3       1.750716e+06
# 4       4.470182e+06
# 5       5.954847e+05
# 6       1.474285e+06
# 7       1.247277e+06
# 8       8.354356e+06
# 9       1.389018e+06
# 10      1.316760e+06
# 11      3.856841e+05
# 12      1.120947e+06
# 13      1.589897e+06
# 14      3.385504e+05
# 15      1.709735e+06
# 16      3.187589e+05
# 17      9.572899e+05
# 18      2.006602e+06
# 19      9.543681e+03
# 20      4.707823e+05
# 21               NaN
# 22      2.159304e+06
# 23      3.990791e+05
# 24      5.039272e+05
# 25               NaN
# 26      6.977634e+05
# 27      3.382391e+04
# 28      2.318576e+06
# 29      1.341463e+07
#             ...
# 1044    0.000000e+00
# 1045    0.000000e+00
# 1046    0.000000e+00
# 1047    3.397131e+05
# 1048    3.147044e+05
# 1049    5.440023e+02
# 1050    1.561710e+07
# 1051    9.423004e+06
# 1052    0.000000e+00
# 1053    0.000000e+00
# 1054    1.905628e+07
# 1055    0.000000e+00
# 1056    4.874504e+03
# 1057    0.000000e+00
# 1058    0.000000e+00
# 1059    8.813562e+05
# 1060    0.000000e+00
# 1061    0.000000e+00
# 1062             NaN
# 1063    0.000000e+00
# 1064    5.675014e+06
# 1065    1.051040e+06
# 1066    0.000000e+00
# 1067    2.869141e+04
# 1068    2.949578e-02
# 1069    0.000000e+00
# 1070    1.725153e+05
# 1071    1.989748e+06
# 1072    0.000000e+00
# 1073             NaN
# Name: pop_max_64, Length: 1074, dtype: float64

# %%
df = df[['ID', 'NAME', 'ISO', 'Year', 'ISO_TIME', 'COORDS', 'BASIN', 'SUBBASIN', 'NATURE',
        'TOTAL_HRS', 'DAY_HRS', 'NIGHT_HRS', 'USA_SSHS',
        
       'PRES_CALC_mean', 'STORM_SPD_mean', 'STORM_DR_mean', 'v_land_kn', 'CALC_pop_exposed',
       'CALC_assets_exposed', "Total damage ('000$)_Adjusted",
         
    # here features from World Bank Indicators:
       'Air transport, freight (million ton-km)',
       'Arable land (hectares per person)', 'Cereal yield (kg per hectare)',
       'Food production index (2004-2006 = 100)', 'GDP growth (annual %)',
       'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$',
       'Life expectancy at birth, total (years)',
       'Mobile cellular subscriptions (per 100 people)',
       'Population density (people per sq. km of land area)',
       'Adjusted savings: education expenditure (% of GNI)',
       'Rural population (% of total population)', 'Income_level_Final',
         
    # Target label at the end  
       'Total Affected', 'pop_max_34'
        ]]

# %% [markdown]
# ### Checking Nulls

# %%
# Checking quantity of missing data. Reusing code from Fabi
def null_cols(data):

    """
    This function takes a dataframe df and shows the columns of df that have NaN values
    and the number of them

    """
    nulls = data.isna().sum()
    nulls = nulls[nulls > 0] / len(data) * 100
    nulls = pd.DataFrame(nulls.sort_values(ascending = False))
    nulls = nulls.reset_index().rename(columns = {"index": "Feature", 0: "% Null rows"})
    return nulls

# %%
null_cols(df)
# Out:
#                                               Feature  % Null rows
# 0                       Total damage ('000$)_Adjusted    31.191806
# 1                                 CALC_assets_exposed    23.556797
# 2                                    CALC_pop_exposed    23.556797
# 3             Air transport, freight (million ton-km)    16.573557
# 4                                             Numeric     9.031657
# 5                                          pop_max_64     9.031657
# 6                                          pop_max_50     9.031657
# 7                                          pop_max_34     9.031657
# 8                               GDP growth (annual %)     4.096834
# 9      Mobile cellular subscriptions (per 100 people)     1.024209
# 10  Adjusted savings: education expenditure (% of ...     0.931099
# 11                      Cereal yield (kg per hectare)     0.931099
# 12                 GDP per capita (constant 2010 US$)     0.837989
# 13                                           USA_SSHS     0.837989
# 14                                     PRES_CALC_mean     0.465549
# 15            Life expectancy at birth, total (years)     0.372439
# 16            Food production index (2004-2006 = 100)     0.372439
# 17                  Arable land (hectares per person)     0.093110
# 18                                               NAME     0.093110

# %% [markdown]
# ### Checking correlations

# %%
df['TOTAL_HRS'].corr(df['Total Affected'])
# Out:
# 0.10277493191414862

# %%
numerical_features = list(df.select_dtypes(include=['float64', 'int64']).columns)

# %%
df_num = df[numerical_features]

# %%
#correlation matrices
corr_num = df_num.corr(method = "spearman")

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = plt.subplot(111)
sns.set(font_scale=1)
sns.heatmap(corr_num, annot=True,  linewidth=1, cmap="BrBG", ax=ax)
bottom, top = ax.get_ylim()             # this fixes a bug where first and last columns were not visualized correctly
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (30.0, 0.0)

# %% [markdown]
# Up to this point, **Total Affected has no stong correlation with any numerical feature**. Anyways, the strongest ones are:
#
# - **corr aprox +-0.3** = 'CALC_pop_Exp', 'Total Damage ('000$)_Adjusted', 'GDP per Capita', 'Net flows from UN', 'Rural Population'
#
# Strong correlations between features are:
#
# - -0.88 for "Rural Population" with "GDP per capita"  + -0.7 for "Rural Population" with "Life Expectancy at birth" ==> **Drop "Rural Population"**
# - -0.76 for "Population Density" with "Arable land Ha/pp"  ==> **Drop "Population density"**, it has lower corr with target than Arable Land
# - +0.83 for 'CALC_pop_Exp' with 'CALC_assets_Exp' ==> **Drop 'CALC_assets_Exposed'**
# - +0.88  for 'NIGHT_HRS' with 'TOTAL_HRS" ==> **Drop 'NIGHT_HRS'**
# - +0.71 for 'Mobile suscriptions' with 'Food Production Index' ==> **Drop 'Mobile suscriptions'** also because there is no mobile suscriptions before 1982

# %% [markdown]
# Let's see what we have after dropping these...

# %%
df = df.drop(['Rural population (% of total population)', 'Population density (people per sq. km of land area)', 'CALC_assets_exposed','NIGHT_HRS','Mobile cellular subscriptions (per 100 people)'], axis=1)

# %%
numerical_features = list(df.select_dtypes(include=['float64', 'int64']).columns)
df_num = df[numerical_features]
#correlation matrices
corr_num = df_num.corr(method = "spearman")

fig, ax = plt.subplots(figsize=(20,20))
ax = plt.subplot(111)
sns.set(font_scale=1)
sns.heatmap(corr_num, annot=True,  linewidth=1, cmap="BrBG", ax=ax)
bottom, top = ax.get_ylim()             # this fixes a bug where first and last columns were not visualized correctly
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (21.0, 0.0)

# %% [markdown]
# ### Boxplots and Pairplots

# %% [markdown]
# - **Boxplotting numerical columns**

# %%
def create_boxplot(column):
    fig, ax = plt.subplots(figsize=(4,4))
    df.boxplot(column = [column])

# %%
for column in df_num.columns:
    create_boxplot(column)

# %% [markdown]
# **WARNING**: Outliers in target 'Total Affected', and features 'CALC_pop_exposed','Total Damage '000$_adjusted','Arable Land', 'GDP Growth', ...

# %% [markdown]
# - **Boxplotting non-numerical columns**:

# %%
#checking non-numerical features 
obj_feats = df.dtypes[df.dtypes == 'object'].index
obj_feats
# Out:
# Index(['NAME', 'ISO', 'ISO_TIME', 'COORDS', 'BASIN', 'SUBBASIN', 'NATURE',
#        'Income_level_Final'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax=sns.boxplot(data=df,
         x='BASIN',
         y='Total Affected')

plt.show()
plt.clf()

# %%
fig, ax = plt.subplots(figsize=(25,5))
ax=sns.boxplot(data=df,
         x='ISO',
         y='Total Affected')

plt.show()
plt.clf()

# %% [markdown]
# - **Pairplot**

# %%
# sns.pairplot(df_num)

# %% [markdown]
# ### Determining skewedness

# %% [markdown]
# Credits to [OpenDataScience](https://medium.com/@ODSC/transforming-skewed-data-for-machine-learning-90e6cc364b0)
#
# We can objectively determine if the variable is skewed using the Shapiro-Wilks test. The null hypothesis for this test is that the data is a sample from a normal distribution, so a p-value less than 0.05 indicates significant skewness.

# %%
from scipy.stats import shapiro

# %%
shapiro(df['Total Affected'])[1]
# Out:
# 0.0

# %%
df['Total Affected'].hist(bins=100)

# %% [markdown]
# The p-value is not surprisingly less than 0.05, so we can conclude that the variable is skewed. A more convenient way of evaluating skewness is with pandas’ ``.skew`` method. It calculates the Fisher–Pearson standardized moment coefficient for all columns in a dataframe.
#
# Checking skeweness for the other features:

# %%
#determine index for continous variables
num_feats = df.dtypes[df.dtypes != 'object'].index

#Calculate skew and sort
skew_feats = df[num_feats].skew().sort_values(ascending = False)
skewness = pd.DataFrame({'Skew': skew_feats})

# %%
skewness
# Out:
#                                                          Skew
# Total damage ('000$)_Adjusted                       12.836028
# Total Affected                                       6.966373
# Arable land (hectares per person)                    5.343659
# Air transport, freight (million ton-km)              2.687817
# Adjusted savings: education expenditure (% of GNI)   2.390530
# Net flows from UN agencies US$                       2.070580
# CALC_pop_exposed                                     1.939554
# GDP per capita (constant 2010 US$)                   1.899897
# STORM_SPD_mean                                       1.853383
# DAY_HRS                                              1.536911
# USA_SSHS                                             0.533831
# Cereal yield (kg per hectare)                        0.351090
# TOTAL_HRS                                            0.221482
# v_land_kn                                            0.159160
# ID                                                   0.001710
# Food production index (2004-2006 = 100)             -0.021499
# GDP growth (annual %)                               -0.560002
# STORM_DR_mean                                       -0.846113
# Year                                                -0.868145
# Life expectancy at birth, total (years)             -0.905111
# PRES_CALC_mean                                      -0.980671

# %% [markdown]
# Checking distribution when applying log function

# %%
# reusing code from Juber
ax=sns.distplot(df['Total Affected'].values)

plt.show()
plt.clf()

log_affected=np.log(df['Total Affected'].values)
ax=sns.distplot(log_affected)

plt.show()
plt.clf()

# %%
ax=sns.distplot(df['Arable land (hectares per person)'].values)

plt.show()
plt.clf()

log_affected=np.log(df['Arable land (hectares per person)'].values)
ax=sns.distplot(log_affected)

plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-0c992454a73c> in <module>
# ----> 1 ax=sns.distplot(df['Arable land (hectares per person)'].values)
#       2
#       3 plt.show()
#       4 plt.clf()
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# ### Applying log to skewed variables

# %%
# Creating list of features to transform, for skew values above 2

feats_to_log = skewness[skewness['Skew'] > 2].index

# %%
feats_to_log

# %%
df[feats_to_log].describe()

# %%
# as log cannot be perfomed to negative numbers, a common technique for handling negative values is to 
# add a constant value to the data prior to applying the log transform. The transformation is 
#therefore log(Y+a) where a is the constant. Some people like to choose a so that min(Y+a) is a very small 
#positive number (like 0.001). Others choose a so that min(Y+a) = 1. For the latter choice, you can show 
# that a = b – min(Y), where b is either a small number or is 1.
# Source : https://blogs.sas.com/content/iml/2011/04/27/log-transformations-how-to-handle-negative-data-values.html

for item in feats_to_log:
    df[item]=np.log((df[item] + 1 - df[item].min()).values)

# %%
for item in feats_to_log:
    ax=sns.distplot(df[item].values)
    ax.set_title(item);
    plt.show()
    plt.clf()

# %% [markdown]
# ### Transforming object variables into numeric with dummy coding

# %%
feats_to_dummy =['BASIN', 'SUBBASIN', 'NATURE','Income_level_Final']

# %%
for feature in feats_to_dummy:
    dummy = pd.get_dummies(df[feature], prefix=feature)
    df = pd.concat([df,dummy], axis=1)

# %%
# Dropping dummed features
df = df.drop(feats_to_dummy, axis=1)

# %% [markdown]
# # Checking resulting dataset

# %%
df['Total Affected'].describe()
# Out:
# count    1.074000e+03
# mean     6.144233e+05
# std      2.045526e+06
# min      2.000000e+00
# 25%      3.123500e+03
# 50%      3.017000e+04
# 75%      2.707850e+05
# max      2.962200e+07
# Name: Total Affected, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 54 columns):
# ID                                                    1074 non-null int64
# NAME                                                  1073 non-null object
# ISO                                                   1074 non-null object
# Year                                                  1074 non-null int64
# ISO_TIME                                              1074 non-null object
# COORDS                                                1074 non-null object
# TOTAL_HRS                                             1074 non-null int64
# DAY_HRS                                               1074 non-null int64
# USA_SSHS                                              1065 non-null float64
# PRES_CALC_mean                                        1069 non-null float64
# STORM_SPD_mean                                        1074 non-null float64
# STORM_DR_mean                                         1074 non-null float64
# v_land_kn                                             1074 non-null float64
# CALC_pop_exposed                                      821 non-null float64
# Total damage ('000$)_Adjusted                         739 non-null float64
# Air transport, freight (million ton-km)               896 non-null float64
# Arable land (hectares per person)                     1073 non-null float64
# Cereal yield (kg per hectare)                         1064 non-null float64
# Food production index (2004-2006 = 100)               1070 non-null float64
# GDP growth (annual %)                                 1030 non-null float64
# GDP per capita (constant 2010 US$)                    1065 non-null float64
# Net flows from UN agencies US$                        1074 non-null float64
# Life expectancy at birth, total (years)               1070 non-null float64
# Adjusted savings: education expenditure (% of GNI)    1064 non-null float64
# Total Affected                                        1074 non-null int64
# BASIN_EP                                              1074 non-null uint8
# BASIN_NAm                                             1074 non-null uint8
# BASIN_NI                                              1074 non-null uint8
# BASIN_SI                                              1074 non-null uint8
# BASIN_SP                                              1074 non-null uint8
# BASIN_WP                                              1074 non-null uint8
# BASIN_ep                                              1074 non-null uint8
# SUBBASIN_AS                                           1074 non-null uint8
# SUBBASIN_BB                                           1074 non-null uint8
# SUBBASIN_CP                                           1074 non-null uint8
# SUBBASIN_CS                                           1074 non-null uint8
# SUBBASIN_EA                                           1074 non-null uint8
# SUBBASIN_EP                                           1074 non-null uint8
# SUBBASIN_GM                                           1074 non-null uint8
# SUBBASIN_NAm                                          1074 non-null uint8
# SUBBASIN_SI                                           1074 non-null uint8
# SUBBASIN_SP                                           1074 non-null uint8
# SUBBASIN_WA                                           1074 non-null uint8
# SUBBASIN_WP                                           1074 non-null uint8
# NATURE_DS                                             1074 non-null uint8
# NATURE_ET                                             1074 non-null uint8
# NATURE_MX                                             1074 non-null uint8
# NATURE_NR                                             1074 non-null uint8
# NATURE_SS                                             1074 non-null uint8
# NATURE_TS                                             1074 non-null uint8
# Income_level_Final_High                               1074 non-null uint8
# Income_level_Final_High_Middle                        1074 non-null uint8
# Income_level_Final_Low                                1074 non-null uint8
# Income_level_Final_Low_Middle                         1074 non-null uint8
# dtypes: float64(16), int64(5), object(4), uint8(29)
# memory usage: 240.3+ KB

# %%
df.columns
# Out:
# Index(['ID', 'NAME', 'ISO', 'Year', 'ISO_TIME', 'COORDS', 'TOTAL_HRS',
#        'DAY_HRS', 'USA_SSHS', 'PRES_CALC_mean', 'STORM_SPD_mean',
#        'STORM_DR_mean', 'v_land_kn', 'CALC_pop_exposed',
#        'Total damage ('000$)_Adjusted',
#        'Air transport, freight (million ton-km)',
#        'Arable land (hectares per person)', 'Cereal yield (kg per hectare)',
#        'Food production index (2004-2006 = 100)', 'GDP growth (annual %)',
#        'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$',
#        'Life expectancy at birth, total (years)',
#        'Adjusted savings: education expenditure (% of GNI)', 'Total Affected',
#        'BASIN_EP', 'BASIN_NAm', 'BASIN_NI', 'BASIN_SI', 'BASIN_SP', 'BASIN_WP',
#        'BASIN_ep', 'SUBBASIN_AS', 'SUBBASIN_BB', 'SUBBASIN_CP', 'SUBBASIN_CS',
#        'SUBBASIN_EA', 'SUBBASIN_EP', 'SUBBASIN_GM', 'SUBBASIN_NAm',
#        'SUBBASIN_SI', 'SUBBASIN_SP', 'SUBBASIN_WA', 'SUBBASIN_WP', 'NATURE_DS',
#        'NATURE_ET', 'NATURE_MX', 'NATURE_NR', 'NATURE_SS', 'NATURE_TS',
#        'Income_level_Final_High', 'Income_level_Final_High_Middle',
#        'Income_level_Final_Low', 'Income_level_Final_Low_Middle'],
#       dtype='object')

# %%
# Arranging again columns:

df = df[[
    # features from cyclones
       'ID', 'NAME', 'ISO', 'Year', 'ISO_TIME', 'COORDS', 'TOTAL_HRS',
       'DAY_HRS', 'USA_SSHS', 'PRES_CALC_mean', 'STORM_SPD_mean',
       'STORM_DR_mean', 'v_land_kn', 'CALC_pop_exposed',
       "Total damage ('000$)_Adjusted", 'BASIN_EP', 'BASIN_NAm', 'BASIN_NI', 'BASIN_SI', 'BASIN_SP', 'BASIN_WP',
       'BASIN_ep', 'SUBBASIN_AS', 'SUBBASIN_BB', 'SUBBASIN_CP', 'SUBBASIN_CS',
       'SUBBASIN_EA', 'SUBBASIN_EP', 'SUBBASIN_GM', 'SUBBASIN_NAm',
       'SUBBASIN_SI', 'SUBBASIN_SP', 'SUBBASIN_WA', 'SUBBASIN_WP', 'NATURE_DS',
       'NATURE_ET', 'NATURE_MX', 'NATURE_NR', 'NATURE_SS', 'NATURE_TS',
         
    # features from World Bank Indicators:           
       'Air transport, freight (million ton-km)',
       'Arable land (hectares per person)', 'Cereal yield (kg per hectare)',
       'Food production index (2004-2006 = 100)', 'GDP growth (annual %)',
       'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$',
       'Life expectancy at birth, total (years)',
       'Adjusted savings: education expenditure (% of GNI)', 
       
       'Income_level_Final_High', 'Income_level_Final_High_Middle',
       'Income_level_Final_Low', 'Income_level_Final_Low_Middle',
    
    # Target label at the end 
        'Total Affected']]

# %%
df.shape
# Out:
# (1074, 54)

# %%
df.to_csv(r'Data_output/Clean_OUTPUT_cyclones.csv', index = False, sep = ';')

# %% [markdown]
# #### Checking correlations again

# %%
df['TOTAL_HRS'].corr(df['Total Affected'])
# Out:
# 0.10377976286933148

# %%
numerical_features = list(df.select_dtypes(include=['float64', 'int64']).columns)
df_num = df[numerical_features]
#correlation matrices
corr_num = df_num.corr(method = "spearman")

fig, ax = plt.subplots(figsize=(20,20))
ax = plt.subplot(111)
sns.set(font_scale=1)
sns.heatmap(corr_num, annot=True,  linewidth=1, cmap="BrBG", ax=ax)
bottom, top = ax.get_ylim()             # this fixes a bug where first and last columns were not visualized correctly
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (21.5, -0.5)
