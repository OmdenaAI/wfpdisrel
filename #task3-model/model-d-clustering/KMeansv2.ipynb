# %% [markdown]
# # KMeans - visualization
#
# Beata Baczynska

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors

from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import seaborn as sns
sns.set()

from ipywidgets import interact
import ipywidgets as widgets

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/Omdena"
# Out:
# /content/drive/My Drive/Colab Notebooks/Omdena

# %%
df = pd.read_csv("OUTPUT_WBI_exposer_cyclones_v2.csv", sep=";")

# %%
df.columns
# Out:
# Index(['SID', 'NAME', 'ISO', 'YEAR', 'BASIN', 'SUB BASIN', 'NATURE',
#        'ISO_TIME', 'COORDS', 'TOTAL_HRS', 'DAY_HRS', 'NIGHT_HRS', 'USA_SSHS',
#        'WIND_CALC_MEAN', 'PRES_CALC_MEAN', 'STORM_SPD_MEAN', 'STORM_DR_MEAN',
#        'V_LAND_KN', '34KN_ASSETS', '64KN_ASSETS', '96KN_ASSETS', 'CPI',
#        'TOTAL_DAMAGE_(000$)', 'TOTAL_DEATHS',
#        'Air transport, freight (million ton-km)',
#        'Arable land (hectares per person)', 'Cereal yield (kg per hectare)',
#        'Food production index (2004-2006 = 100)', 'GDP growth (annual %)',
#        'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$',
#        'Life expectancy at birth, total (years)',
#        'Mobile cellular subscriptions (per 100 people)',
#        'Population density (people per sq. km of land area)',
#        'Adjusted savings: education expenditure (% of GNI)',
#        'Rural population (% of total population)', 'Income_level_Final',
#        'pop_max_34_adj', 'pop_max_50_adj', 'pop_max_64_adj', 'TOTAL_AFFECTED'],
#       dtype='object')

# %%
# choosing some numeric features
cols = ['YEAR', 'TOTAL_HRS', 'NIGHT_HRS', 'USA_SSHS', 'WIND_CALC_MEAN', 'PRES_CALC_MEAN', 'STORM_SPD_MEAN', 'STORM_DR_MEAN', 
        'V_LAND_KN', 'CPI', 'TOTAL_DAMAGE_(000$)', 'TOTAL_DEATHS', 'Air transport, freight (million ton-km)', 
        'Arable land (hectares per person)', 'Cereal yield (kg per hectare)', 'Food production index (2004-2006 = 100)', 
        'GDP growth (annual %)', 'GDP per capita (constant 2010 US$)', 'Net flows from UN agencies US$', 
        'Life expectancy at birth, total (years)', 'Mobile cellular subscriptions (per 100 people)', 
        'Population density (people per sq. km of land area)', 'Adjusted savings: education expenditure (% of GNI)', 
        'Rural population (% of total population)', 'pop_max_34_adj', 'pop_max_50_adj', 'pop_max_64_adj', 'TOTAL_AFFECTED']
df_cols = df[cols]
df_cols
# Out:
#       YEAR  TOTAL_HRS  ...  pop_max_64_adj  TOTAL_AFFECTED
# 0     1949          0  ...    5.339257e+05          194046
# 1     1950          6  ...    2.985054e+06          642117
# 2     1951         15  ...    6.550875e+05           20200
# 3     1951         15  ...    5.896887e+05           60000
# 4     1952          3  ...    1.505678e+06             103
# ...    ...        ...  ...             ...             ...
# 1000  2019          9  ...    0.000000e+00            1100
# 1001  2019          3  ...    0.000000e+00         1501500
# 1002  2019          3  ...             NaN          345311
# 1003  2019          0  ...    9.133066e+04          400094
# 1004  2019         21  ...    0.000000e+00        20000000
#
# [1005 rows x 28 columns]

# %%
df_cols_dict = {}
i = 0
for x in cols:
  df_cols_dict[i] = x
  i+=1

df_cols_dict
# Out:
# {0: 'YEAR',
#  1: 'TOTAL_HRS',
#  2: 'NIGHT_HRS',
#  3: 'USA_SSHS',
#  4: 'WIND_CALC_MEAN',
#  5: 'PRES_CALC_MEAN',
#  6: 'STORM_SPD_MEAN',
#  7: 'STORM_DR_MEAN',
#  8: 'V_LAND_KN',
#  9: 'CPI',
#  10: 'TOTAL_DAMAGE_(000$)',
#  11: 'TOTAL_DEATHS',
#  12: 'Air transport, freight (million ton-km)',
#  13: 'Arable land (hectares per person)',
#  14: 'Cereal yield (kg per hectare)',
#  15: 'Food production index (2004-2006 = 100)',
#  16: 'GDP growth (annual %)',
#  17: 'GDP per capita (constant 2010 US$)',
#  18: 'Net flows from UN agencies US$',
#  19: 'Life expectancy at birth, total (years)',
#  20: 'Mobile cellular subscriptions (per 100 people)',
#  21: 'Population density (people per sq. km of land area)',
#  22: 'Adjusted savings: education expenditure (% of GNI)',
#  23: 'Rural population (% of total population)',
#  24: 'pop_max_34_adj',
#  25: 'pop_max_50_adj',
#  26: 'pop_max_64_adj',
#  27: 'TOTAL_AFFECTED'}

# %%
#Dropping nan values
df_cols.dropna(inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Scatter before normalization

# %%
@interact( x = cols, y = cols)
def scatt(x, y):
  plt.scatter(df[str(x)], df[str(y)])
  plt.xlabel(x)
  plt.ylabel(y)
  plt.show()
# Out:
# interactive(children=(Dropdown(description='x', options=('YEAR', 'TOTAL_HRS', 'NIGHT_HRS', 'USA_SSHS', 'WIND_C…

# %%
colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 
          'goldenrod', 'lightcyan', 'navy', 'gold', 'aliceblue', 'fuchsia',
          'lime', 'yellow', 'sienna', 'black', 'crimson', 'orange']
vectorizer = np.vectorize(lambda x: colors[x % len(colors)])

# %%
x = df_cols.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_cols_norm = pd.DataFrame(x_scaled)
df_cols_norm
# Out:
#            0         1         2   ...        25        26            27
# 0    0.000000  0.000000  0.043478  ...  0.002084  0.004415  3.375194e-04
# 1    0.000000  0.954545  0.956522  ...  0.004257  0.002873  4.901695e-03
# 2    0.000000  0.000000  0.043478  ...  0.034074  0.004279  1.458622e-02
# 3    0.020833  0.409091  0.434783  ...  0.012269  0.010718  1.097191e-03
# 4    0.041667  0.818182  0.826087  ...  0.011350  0.016998  8.777261e-07
# ..        ...       ...       ...  ...       ...       ...           ...
# 530  1.000000  0.954545  0.956522  ...  0.005041  0.010194  3.375194e-04
# 531  1.000000  0.136364  0.086957  ...  0.014167  0.010527  8.551010e-03
# 532  1.000000  0.409091  0.434783  ...  0.087534  0.076698  1.687928e-02
# 533  1.000000  0.136364  0.086957  ...  0.015943  0.012151  3.384647e-04
# 534  1.000000  0.954545  0.956522  ...  0.022799  0.015049  3.375194e-04
#
# [535 rows x 28 columns]

# %% [markdown]
# ## Choosing paramethrs: number of clusters

# %%
@interact (n_clusters=(1, 20, 1))
def for_clustering(n_clusters=5):
  global m
  m = KMeans(n_clusters=n_clusters)
  m.fit(df_cols_norm)

  global clusters
  global number_of_clusters
  number_of_clusters = len(np.unique(clusters))
  clusters = m.labels_
  return "Number of clusters: " + str(number_of_clusters)
# Out:
# interactive(children=(IntSlider(value=5, description='n_clusters', max=20, min=1), Output()), _dom_classes=('w…

# %%
features_array = [('YEAR', 0) , ('TOTAL_HRS', 1), ('NIGHT_HRS', 2), ('USA_SSHS',3), ('WIND_CALC_MEAN',4), ('PRES_CALC_MEAN', 5),
 ('STORM_SPD_MEAN', 6), ('STORM_DR_MEAN', 7), ('V_LAND_KN', 8), ('CPI', 9), ('TOTAL_DAMAGE_(000$)',10), ('TOTAL_DEATHS',11),
 ('Air transport, freight (million ton-km)',12), ('Arable land (hectares per person)',13), ('Cereal yield (kg per hectare)',14),
 ('Food production index (2004-2006 = 100)',15), ('GDP growth (annual %)',16), ('GDP per capita (constant 2010 US$)',17),
 ('Net flows from UN agencies US$',18), ('Life expectancy at birth, total (years)',19),
 ('Mobile cellular subscriptions (per 100 people)',20), ('Population density (people per sq. km of land area)',21),
 ('Adjusted savings: education expenditure (% of GNI)',22), ('Rural population (% of total population)',23),
 ('pop_max_34_adj',24), ('pop_max_50_adj',25), ('pop_max_64_adj',26), ('TOTAL_AFFECTED', 27)]

# %% [markdown]
# ## Scatter with clusters, after normalization

# %%
@interact (x = features_array, y = features_array, 
           x_min=(0.0, 0.9, 0.1), x_max=(0.1, 1.0, 0.1), 
           y_min=(0.0, 0.9, 0.1), y_max=(0.1, 1.0, 0.1))
def scatt(x, y, x_min=0.0, x_max=1.0, y_min=0.0, y_max=1.0):
  plt.scatter(df_cols_norm[x], df_cols_norm[y], c=vectorizer(clusters))
  axes = plt.gca()
  plt.xlabel(df_cols_dict[x])
  plt.ylabel(df_cols_dict[y])
  axes.set_xlim([x_min, x_max])
  axes.set_ylim([y_min, y_max])
  plt.show()
# Out:
# interactive(children=(Dropdown(description='x', options=(('YEAR', 0), ('TOTAL_HRS', 1), ('NIGHT_HRS', 2), ('US…

# %%
for cluster in range(number_of_clusters):
  print()
  print(cluster)
  print("color: " + colors[cluster])
  for x in range(len(features_array)):
    print(features_array[x][0] + " : " + str(m.cluster_centers_[cluster][x]))
# Out:
# 0
# color: royalblue
# YEAR : 0.8014601139601141
# TOTAL_HRS : 0.3053613053613052
# NIGHT_HRS : 0.2110739502043849
# USA_SSHS : 0.5504273504273505
# WIND_CALC_MEAN : 0.3019324643981268
# PRES_CALC_MEAN : 0.9683269369953067
# STORM_SPD_MEAN : 0.18574624649101054
# STORM_DR_MEAN : 0.7202028780407479
# V_LAND_KN : 0.39087032575743424
# CPI : 0.8116582123005833
# TOTAL_DAMAGE_(000$) : 0.003281415578752561
# TOTAL_DEATHS : 0.0007630011171369173
# Air transport, freight (million ton-km) : 0.060300167557969526
# Arable land (hectares per person) : 0.02560476983822411
# Cereal yield (kg per hectare) : 0.4225028108551838
# Food production index (2004-2006 = 100) : 0.6698463952149061
# GDP growth (annual %) : 0.5943997127581896
# GDP per capita (constant 2010 US$) : 0.06301771264986691
# Net flows from UN agencies US$ : 0.15026459165739303
# Life expectancy at birth, total (years) : 0.6987301691835227
# Mobile cellular subscriptions (per 100 people) : 0.41781732468040966
# Population density (people per sq. km of land area) : 0.19273854287519307
# Adjusted savings: education expenditure (% of GNI) : 0.17701495349771826
# Rural population (% of total population) : 0.5642231898746682
# pop_max_34_adj : 0.10444168503518195
# pop_max_50_adj : 0.06196601814300986
# pop_max_64_adj : 0.08770797338451519
# TOTAL_AFFECTED : 0.046472797670775605
#
# 1
# color: maroon
# YEAR : 0.7287581699346407
# TOTAL_HRS : 0.5770944741532977
# NIGHT_HRS : 0.4936061381074168
# USA_SSHS : 0.4823529411764706
# WIND_CALC_MEAN : 0.2984525980740928
# PRES_CALC_MEAN : 0.9672261886581635
# STORM_SPD_MEAN : 0.3673762250515885
# STORM_DR_MEAN : 0.2570786189472047
# V_LAND_KN : 0.4669330077260328
# CPI : 0.737241071961255
# TOTAL_DAMAGE_(000$) : 0.049507540431191474
# TOTAL_DEATHS : 0.0002811546329224419
# Air transport, freight (million ton-km) : 0.3998480498768582
# Arable land (hectares per person) : 0.1231898543009118
# Cereal yield (kg per hectare) : 0.6889610981869209
# Food production index (2004-2006 = 100) : 0.5955593186803974
# GDP growth (annual %) : 0.48965106993779267
# GDP per capita (constant 2010 US$) : 0.7567611449582405
# Net flows from UN agencies US$ : 0.0007912498316792749
# Life expectancy at birth, total (years) : 0.8891377001186453
# Mobile cellular subscriptions (per 100 people) : 0.4783224813501956
# Population density (people per sq. km of land area) : 0.1740501059546058
# Adjusted savings: education expenditure (% of GNI) : 0.24241634136063617
# Rural population (% of total population) : 0.11579178087458747
# pop_max_34_adj : 0.11616276000567254
# pop_max_50_adj : 0.0779509281797504
# pop_max_64_adj : 0.09196859182490542
# TOTAL_AFFECTED : 0.006423490658900865
#
# 2
# color: forestgreen
# YEAR : 0.8742492492492496
# TOTAL_HRS : 0.9004914004914009
# NIGHT_HRS : 0.8397963180571877
# USA_SSHS : 0.5567567567567567
# WIND_CALC_MEAN : 0.32445587366936773
# PRES_CALC_MEAN : 0.9660003324093389
# STORM_SPD_MEAN : 0.18797750593903484
# STORM_DR_MEAN : 0.697368624288086
# V_LAND_KN : 0.3889857811197942
# CPI : 0.8875868724421079
# TOTAL_DAMAGE_(000$) : 0.005532436118270564
# TOTAL_DEATHS : 0.0009385673028935416
# Air transport, freight (million ton-km) : 0.12343521675064913
# Arable land (hectares per person) : 0.024978262460339247
# Cereal yield (kg per hectare) : 0.49380758665733654
# Food production index (2004-2006 = 100) : 0.7795186666828845
# GDP growth (annual %) : 0.6019786259253229
# GDP per capita (constant 2010 US$) : 0.07390009008858202
# Net flows from UN agencies US$ : 0.18573708110889542
# Life expectancy at birth, total (years) : 0.7184357450726495
# Mobile cellular subscriptions (per 100 people) : 0.5862627330990188
# Population density (people per sq. km of land area) : 0.18092572448580857
# Adjusted savings: education expenditure (% of GNI) : 0.1702610530757407
# Rural population (% of total population) : 0.5651405185049851
# pop_max_34_adj : 0.10139940904655584
# pop_max_50_adj : 0.052991570851667794
# pop_max_64_adj : 0.10207790577856245
# TOTAL_AFFECTED : 0.0431878989342939
#
# 3
# color: mediumorchid
# YEAR : 0.46253360215053807
# TOTAL_HRS : 0.86766862170088
# NIGHT_HRS : 0.8211781206171107
# USA_SSHS : 0.5129032258064516
# WIND_CALC_MEAN : 0.30506611501795283
# PRES_CALC_MEAN : 0.9686328007334484
# STORM_SPD_MEAN : 0.21467099297946335
# STORM_DR_MEAN : 0.639176789696372
# V_LAND_KN : 0.4264372812066818
# CPI : 0.46779297309151013
# TOTAL_DAMAGE_(000$) : 0.0026912960862714233
# TOTAL_DEATHS : 0.009377721151279403
# Air transport, freight (million ton-km) : 0.0248737457373418
# Arable land (hectares per person) : 0.05430596515446533
# Cereal yield (kg per hectare) : 0.34623002958549326
# Food production index (2004-2006 = 100) : 0.3596222525478353
# GDP growth (annual %) : 0.5796427566055722
# GDP per capita (constant 2010 US$) : 0.07343598799393648
# Net flows from UN agencies US$ : 0.187258284586856
# Life expectancy at birth, total (years) : 0.6267049874606587
# Mobile cellular subscriptions (per 100 people) : 0.0227060730939756
# Population density (people per sq. km of land area) : 0.1308346457009815
# Adjusted savings: education expenditure (% of GNI) : 0.16785105183085477
# Rural population (% of total population) : 0.5954775829839083
# pop_max_34_adj : 0.08317974932679963
# pop_max_50_adj : 0.058367250681885106
# pop_max_64_adj : 0.0355403350333131
# TOTAL_AFFECTED : 0.0316668686344128
#
# 4
# color: tan
# YEAR : 0.3171296296296299
# TOTAL_HRS : 0.32042648709315336
# NIGHT_HRS : 0.21792807300053668
# USA_SSHS : 0.5753086419753086
# WIND_CALC_MEAN : 0.39594887912816235
# PRES_CALC_MEAN : 0.9355207746697793
# STORM_SPD_MEAN : 0.20940679386244
# STORM_DR_MEAN : 0.708045785573929
# V_LAND_KN : 0.530997275498368
# CPI : 0.31719635003021734
# TOTAL_DAMAGE_(000$) : 0.0009026581462867264
# TOTAL_DEATHS : 0.000820427987702949
# Air transport, freight (million ton-km) : 0.011890544232957281
# Arable land (hectares per person) : 0.0568198387134774
# Cereal yield (kg per hectare) : 0.20589986709617247
# Food production index (2004-2006 = 100) : 0.26869131357580195
# GDP growth (annual %) : 0.52398780923143
# GDP per capita (constant 2010 US$) : 0.05057409718128569
# Net flows from UN agencies US$ : 0.12682623675071555
# Life expectancy at birth, total (years) : 0.5110111667527105
# Mobile cellular subscriptions (per 100 people) : 0.0017588673370095287
# Population density (people per sq. km of land area) : 0.10438411787279281
# Adjusted savings: education expenditure (% of GNI) : 0.15942278618291245
# Rural population (% of total population) : 0.6646651682902263
# pop_max_34_adj : 0.03325555588818352
# pop_max_50_adj : 0.02880117478296085
# pop_max_64_adj : 0.01454724708652963
# TOTAL_AFFECTED : 0.014883116740504394
