# %% [markdown]
# ## Fuction def to merge WBI dataset with cyclone dataset
# *@XavierTorres*

# %%
import numpy as np
import pandas as pd

# %%
#Importing WBI Dataset (the final and cleaned one, called OUTPUT....)
df_WBI = pd.read_csv('C:/Users/torre/Documents/Local Omdena WFP files/WorldBank/Part1/OUTPUT_WBI_Selection_Country_Year.csv', sep=';', low_memory = False)

# %%
#Importing cyclones dataset... we use here a sample, as the final dataset is work in process
df_emdat = pd.read_csv('C:/Users/torre/Documents/Local Omdena WFP files/WorldBank/Part1/emdat_names.csv', sep=';', low_memory = False)

# %% [markdown]
# > Note: Function below only works if country names from both datasets are the same and there are no countries in the cyclones dataset missing in the WBI dataset

# %%
df_WBI.head()
# Out:
#      Country Name Country Code                              Series Name  1960  \
# 0     Afghanistan          AFG  Access to electricity (% of population)   NaN
# 1         Albania          ALB  Access to electricity (% of population)   NaN
# 2         Algeria          DZA  Access to electricity (% of population)   NaN
# 3  American Samoa          ASM  Access to electricity (% of population)   NaN
# 4         Andorra          AND  Access to electricity (% of population)   NaN
#
#    1961  1962  1963  1964  1965  1966  ...       2012        2013        2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   69.10000   70.153481   89.500000
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.00000  100.000000  100.000000
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...   98.76466   99.580971   99.877052
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN         NaN         NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.00000  100.000000  100.000000
#
#          2015        2016   2017  2018  2019  Income_level   Indicator_CAT
# 0   71.500000   97.700000   97.7   NaN   NaN           Low  Infrastructure
# 1  100.000000  100.000000  100.0   NaN   NaN   High_Middle  Infrastructure
# 2   99.943069   99.992317  100.0   NaN   NaN   High_Middle  Infrastructure
# 3         NaN         NaN    NaN   NaN   NaN   High_Middle  Infrastructure
# 4  100.000000  100.000000  100.0   NaN   NaN          High  Infrastructure
#
# [5 rows x 65 columns]

# %%
df_emdat.head()
# Out:
#    Unnamed      0  Year  Seq  ISO    Group        Subgroup   Type  \
# 0      392   1827  1973    2  ARG  Natural  Meteorological  Storm
# 1      703   3460  1986  137  ARG  Natural  Meteorological  Storm
# 2     1639  10791  2000  839  ARG  Natural  Meteorological  Storm
# 3     1644  10796  2000  607  ARG  Natural  Meteorological  Storm
# 4      209   1000  1966  117  ASM  Natural  Meteorological  Storm
#
#             Subtype               Subsubtype  ... End day Total deaths  \
# 0  Convective storm                  Tornado  ...     1.0         60.0
# 1  Convective storm                  Tornado  ...     NaN          1.0
# 2  Convective storm  Lightning/Thunderstorms  ...    27.0          1.0
# 3  Convective storm    Winter storm/Blizzard  ...     NaN          NaN
# 4  Tropical cyclone                      NaN  ...     NaN         90.0
#
#   Num injured Num affected Num homeless Total affected  \
# 0       300.0          NaN          NaN          300.0
# 1         NaN       1000.0          NaN         1000.0
# 2         NaN          NaN        430.0          430.0
# 3         NaN          NaN          NaN            NaN
# 4         NaN          NaN          NaN            NaN
#
#   Reconstruction cost ('000$) Insured losses ('000$) Total damage ('000$)  \
# 0                         NaN                    NaN                  NaN
# 1                         NaN                    NaN                  NaN
# 2                         NaN                    NaN                  NaN
# 3                         NaN                    NaN                  NaN
# 4                         NaN                    NaN                  NaN
#
#          CPI
# 0  17.366986
# 1  42.873130
# 2  67.355759
# 3  67.355759
# 4  12.696028
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Defining the function

# %%
# Creating a function that merges both datasets, WBI and cyclones

def merge_WBI_cyclones(df_WBI, df_emdat):
    
    # Let's add columns without numbers on the right of the cyclone dataset
    series_list = df_WBI['Series Name'].unique()
    for item in series_list:
        df_emdat[item] = np.nan
    
    # Let's also add the column 'Income_level' inherited from WBI dataset
    df_emdat['Income_level'] = np.nan
    
    # let's iterate row by row in cyclones dataset and assign corresponding value to each series columns, 
    # depending on the year and country of that row 
    for i in range(len(df_emdat)):
        curr_country = df_emdat.loc[i,'ISO']
        curr_year = str(df_emdat.loc[i,'Year'])
        
        for serie in series_list:
            #Step 1. selecting row in WBI dataset
            item_selected = df_WBI.loc[(df_WBI['Country Code'] == curr_country) & (df_WBI['Series Name'] == serie)]
            
            #Step 2. Selecting the value for the 'curr_year' column and assigning to current row in cyclone dataset
            data1 = float(item_selected[curr_year])
            data2 = str(item_selected['Income_level'].values)
            df_emdat.loc[i,serie] = data1
            df_emdat.loc[i,'Income_level'] = data2
    
    return

# %%
# Running the function. It lasts about 8-10 minutes to complete
merge_WBI_cyclones(df_WBI, df_emdat)

# %%
df_emdat.head()
# Out:
#    Unnamed      0  Year  Seq  ISO    Group        Subgroup   Type  \
# 0      392   1827  1973    2  ARG  Natural  Meteorological  Storm
# 1      703   3460  1986  137  ARG  Natural  Meteorological  Storm
# 2     1639  10791  2000  839  ARG  Natural  Meteorological  Storm
# 3     1644  10796  2000  607  ARG  Natural  Meteorological  Storm
# 4      209   1000  1966  117  ASM  Natural  Meteorological  Storm
#
#             Subtype               Subsubtype  ...  \
# 0  Convective storm                  Tornado  ...
# 1  Convective storm                  Tornado  ...
# 2  Convective storm  Lightning/Thunderstorms  ...
# 3  Convective storm    Winter storm/Blizzard  ...
# 4  Tropical cyclone                      NaN  ...
#
#   Rural population (% of total population)  \
# 0                                   19.842
# 1                                   14.555
# 2                                   10.858
# 3                                   10.858
# 4                                   31.250
#
#   School enrollment, primary (% gross) School enrollment, secondary (% gross)  \
# 0                            105.59223                               49.91177
# 1                            107.02452                               70.09199
# 2                            115.69413                               95.93661
# 3                            115.69413                               95.93661
# 4                                  NaN                                    NaN
#
#   School enrollment, tertiary (% gross) Secondary education, duration (years)  \
# 0                              19.61808                                   5.0
# 1                              37.42499                                   5.0
# 2                              53.96481                                   6.0
# 3                              53.96481                                   6.0
# 4                                   NaN                                   NaN
#
#   Tuberculosis case detection rate (%, all forms)  \
# 0                                             NaN
# 1                                             NaN
# 2                                            87.0
# 3                                            87.0
# 4                                             NaN
#
#   Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                               15.0
# 3                                               15.0
# 4                                                NaN
#
#   Urban population (% of total population)  \
# 0                                   80.158
# 1                                   85.445
# 2                                   89.142
# 3                                   89.142
# 4                                   68.750
#
#   Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          22.819001
# 3                                          22.819001
# 4                                                NaN
#
#       Income_level
# 0  ['High_Middle']
# 1  ['High_Middle']
# 2  ['High_Middle']
# 3  ['High_Middle']
# 4  ['High_Middle']
#
# [5 rows x 138 columns]

# %%
# Writing to csv the final Dataset to be merged with other dataset from cyclones...

df_emdat.to_csv(r'C:/Users/torre/Documents/Local Omdena WFP files/WorldBank/Part1/OUTPUT_WBI_cyclones_merged.csv', index = False, sep = ';')
