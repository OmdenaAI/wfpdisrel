# %%
#Import data - Took only required columns from the dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
ds = pd.read_csv('C:/Users/Desktop/Challenge/WBI/ORIGINAL_POPULATION_BY_AGE_BOTH_SEXES.csv', encoding='windows-1252')

# %%
#Explore the first few rows of the dataset - Could see for each country we could see around 15 rows
ds.head(20)
# Out:
#     Index      Country  Notes  Country code  Parent code  Referencedate  \
# 0       1  Afghanistan    NaN             4         5501           1950
# 1       2  Afghanistan    NaN             4         5501           1955
# 2       3  Afghanistan    NaN             4         5501           1960
# 3       4  Afghanistan    NaN             4         5501           1965
# 4       5  Afghanistan    NaN             4         5501           1970
# 5       6  Afghanistan    NaN             4         5501           1975
# 6       7  Afghanistan    NaN             4         5501           1980
# 7       8  Afghanistan    NaN             4         5501           1985
# 8       9  Afghanistan    NaN             4         5501           1990
# 9      10  Afghanistan    NaN             4         5501           1995
# 10     11  Afghanistan    NaN             4         5501           2000
# 11     12  Afghanistan    NaN             4         5501           2005
# ...

# %%
# Checking the number of null values. Notes column can be ignored.
ds.isnull().sum()
# Out:
# Index               0
# Country             0
# Notes            2460
# Country code        0
# Parent code         0
# Referencedate       0
# TOTAL POP           0
# 0-4(%)              0
# 5-9(%)              0
# 10-14(%)            0
# 15-19(%)            0
# 20-39(%)            0
# 40-59(%)            0
# 60+ (%)             0
# dtype: int64

# %%
#value_counts() with default parameters
ds['Country'].value_counts()
# Out:
# Ecuador              15
# Malawi               15
# Guinea               15
# New Zealand          15
# Sudan                15
#                      ..
# Equatorial Guinea    15
# Bhutan               15
# Mauritania           15
# Gambia               15
# Bahrain              15
# Name: Country, Length: 201, dtype: int64

# %%
#value_counts() with default parameters.Sanitary check on column Country to confirm that each country has 15 rows( 1950- 2020)
vc = ds.Country.value_counts()
vc[vc>15].index.tolist()
# Out:
# []

# %%
ds1 = pd.read_csv('C:/Users/Desktop/Challenge/WBI/0_MERGED_World_Development_Indicators.csv', encoding='windows-1252')
ds1.head(20)
# Out:
#       Country Name Country Code  \
# 0   American Samoa          ASM
# 1   American Samoa          ASM
# 2   American Samoa          ASM
# 3   American Samoa          ASM
# 4   American Samoa          ASM
# 5   American Samoa          ASM
# 6   American Samoa          ASM
# 7   American Samoa          ASM
# 8   American Samoa          ASM
# 9   American Samoa          ASM
# 10  American Samoa          ASM
# 11  American Samoa          ASM
# 12  American Samoa          ASM
# 13  American Samoa          ASM
# 14  American Samoa          ASM
# 15  American Samoa          ASM
# 16  American Samoa          ASM
# 17  American Samoa          ASM
# 18  American Samoa          ASM
# 19  American Samoa          ASM
#
#                                           Series Name  \
# 0   Access to clean fuels and technologies for coo...
# 1             Access to electricity (% of population)
# 2   Access to electricity, rural (% of rural popul...
# ...

# %%
ds1['Country Name'].value_counts()
#Series Name 1429 different values for each country
# Out:
# Cote d'Ivoire      1429
# Slovak Republic    1429
# Iraq               1429
# Montenegro         1429
# Cabo Verde         1429
#                    ...
# Netherlands        1429
# Jordan             1429
# Sri Lanka          1429
# Austria            1429
# Congo, Rep.        1429
# Name: Country Name, Length: 217, dtype: int64

# %%
ds1['Series Name'].value_counts()
#total 217 Countries
# Out:
# Service exports (BoP, current US$)                                                        217
# Tuberculosis treatment success rate (% of new cases)                                      217
# Insurance and financial services (% of service imports, BoP)                              217
# Logistics performance index: Ability to track and trace consignments (1=low to 5=high)    217
# Unemployment, total (% of total labor force) (national estimate)                          217
#                                                                                          ...
# Agricultural raw materials imports (% of merchandise imports)                             217
# ICT goods imports (% total goods imports)                                                 217
# Incidence of malaria (per 1,000 population at risk)                                       217
# Employers, male (% of male employment) (modeled ILO estimate)                             217
# ...

# %%
#All countries have 1429 series values
vc1 = ds1['Country Name'].value_counts()
vc1[vc1>1429].index.tolist()
# Out:
# []

# %% [markdown]
# # Our goal is to Downsize the no.of series names from  1429 to 80-100 series and join it with Population dataset

# %%
#descriptive statistics for all the columns
ds1.describe(include='all')
# Out:
#          Country Name Country Code                         Series Name  \
# count          310093       310093                              310093
# unique            217          217                                1429
# top     Cote d'Ivoire          MAF  Service exports (BoP, current US$)
# freq             1429         1429                                 217
#
#            Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# count           310093        310093        310093        310093
# unique            1429         27218         30300         31829
# top     IC.FRM.THEV.ZS            ..            ..            ..
# freq               217        279848        276933        275126
#
#        1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2010 [YR2010]  \
# count         310093        310093        310093  ...        310093
# unique         31879         32351         33880  ...        133974
# top               ..            ..            ..  ...            ..
# ...

# %%
#The number of entries in the dataset:
print(ds1.shape)
# Out:
# (310093, 64)

# %%
ds1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]',
#        '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]', '1967 [YR1967]',
#        '1968 [YR1968]', '1969 [YR1969]', '1970 [YR1970]', '1971 [YR1971]',
#        '1972 [YR1972]', '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]',
#        '1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]',
#        '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]',
#        '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]',
#        '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]',
#        '1992 [YR1992]', '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]',
#        '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
# ...

# %%
India_df1 = ds1[ds1['Country Name']=='India']

# %%
India_df1.head(10)
# Out:
#        Country Name Country Code  \
# 234356        India          IND
# 234357        India          IND
# 234358        India          IND
# 234359        India          IND
# 234360        India          IND
# 234361        India          IND
# 234362        India          IND
# 234363        India          IND
# 234364        India          IND
# 234365        India          IND
#
#                                               Series Name        Series Code  \
# 234356  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 234357            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 234358  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 234359  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 234360  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
# 234361  Account ownership at a financial institution o...  FX.OWN.TOTL.FE.ZS
# ...

# %% [markdown]
# Need to understand what all series can be included , correlation may not be feasible here need to explore the series and get which may impact us and bring that data alone for further analysis
