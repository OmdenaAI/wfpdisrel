# %% [markdown]
# # Took the World Bank Indicators per country data provided and took for Country ' India' alone for testing and then from the column 'Series Name' took rows related to 'GDP'
# # Took the  'Population pyramid per country' data and for Country 'India'
# # Merged both the datasets.

# %%
import pandas as pd 
ds = pd.read_csv('C:/Users/Desktop/Challenge/WBI/0_MERGED_World_Development_Indicators.csv', encoding='windows-1252')

# %%
print(ds.shape)
# Out:
# (310093, 64)

# %%
ds.head(10)
# Out:
#      Country Name Country Code  \
# 0  American Samoa          ASM
# 1  American Samoa          ASM
# 2  American Samoa          ASM
# 3  American Samoa          ASM
# 4  American Samoa          ASM
# 5  American Samoa          ASM
# 6  American Samoa          ASM
# 7  American Samoa          ASM
# 8  American Samoa          ASM
# 9  American Samoa          ASM
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
# 5  Account ownership at a financial institution o...  FX.OWN.TOTL.FE.ZS
# 6  Account ownership at a financial institution o...  FX.OWN.TOTL.MA.ZS
# ...

# %%
ds.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]',
#        '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]', '1967 [YR1967]',
#        '1968 [YR1968]', '1969 [YR1969]', '1970 [YR1970]', '1971 [YR1971]',
#        '1972 [YR1972]', '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]',
#        '1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]',
#        '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]',
#        '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]',
#        '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]',
#        '1992 [YR1992]', '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]',
#        '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
# ...

# %%
India_df1 = ds[ds['Country Name']=='India']

# %%
India_df1.head(40)
# Out:
#        Country Name Country Code  \
# 234356        India          IND
# 234357        India          IND
# 234358        India          IND
# 234359        India          IND
# 234360        India          IND
# 234361        India          IND
# 234362        India          IND
# 234363        India          IND
# 234364        India          IND
# 234365        India          IND
# 234366        India          IND
# 234367        India          IND
# 234368        India          IND
# 234369        India          IND
# 234370        India          IND
# 234371        India          IND
# 234372        India          IND
# 234373        India          IND
# 234374        India          IND
# 234375        India          IND
# 234376        India          IND
# 234377        India          IND
# 234378        India          IND
# 234379        India          IND
# 234380        India          IND
# 234381        India          IND
# 234382        India          IND
# ...

# %%
print(India_df1.shape)
India_df1.dropna(inplace = True)
print(India_df1.shape)
# Out:
# (1429, 64)
# (1429, 64)
# c:\users\bgeethan\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
India_df1.head(10)
# Out:
#        Country Name Country Code  \
# 234356        India          IND
# 234357        India          IND
# 234358        India          IND
# 234359        India          IND
# 234360        India          IND
# 234361        India          IND
# 234362        India          IND
# 234363        India          IND
# 234364        India          IND
# 234365        India          IND
#
#                                               Series Name        Series Code  \
# 234356  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 234357            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 234358  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 234359  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 234360  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
# 234361  Account ownership at a financial institution o...  FX.OWN.TOTL.FE.ZS
# ...

# %%
India_final1 = India_df1[India_df1['Series Name'].str.contains("GDP")]

# %%
ds2 = pd.read_csv('C:/Users/bgeethan/Desktop/Challenge/WBI/WPP2019_POP_F07_1_POPULATION_BY_AGE_BOTH_SEXES.csv', encoding='windows-1252')

# %%
print(ds2.shape)
# Out:
# (201, 22)

# %%
ds2.head(10)
# Out:
#    Index              Country  Notes  Country code          Type  Parent code  \
# 0      1          Afghanistan    NaN             4  Country/Area         5501
# 1      2              Albania    NaN             8  Country/Area          925
# 2      3              Algeria    NaN            12  Country/Area          912
# 3      4               Angola    NaN            24  Country/Area          911
# 4      5  Antigua and Barbuda    NaN            28  Country/Area          915
# 5      6            Argentina    NaN            32  Country/Area          931
# 6      7              Armenia    NaN            51  Country/Area          922
# 7      8                Aruba   13.0           533  Country/Area          915
# 8      9            Australia   15.0            36  Country/Area          927
# 9     10              Austria    NaN            40  Country/Area          926
#
#    Reference date (as of 1 July) TOTAL POP      0-4      5-9  ...     20-39  \
# ...

# %%
India_df2 = ds2[ds2['Country']=='India']

# %%
India_df2.head(10)
# Out:
#     Index Country  Notes  Country code          Type  Parent code  \
# 85     86   India    NaN           356  Country/Area         5501
#
#     Reference date (as of 1 July)    TOTAL POP        0-4        5-9  ...  \
# 85                           2020   1,380,004    116,880    117,982   ...
#
#         20-39      40-59        60+ 0-4(%) 5-9(%) 10-14(%) 15-19(%) 20-39(%)  \
# 85   455,538    297,792    139,610    8.5%   8.5%     9.1%     9.1%    33.0%
#
#    40-59(%) 60+ (%)
# 85    21.6%   10.1%
#
# [1 rows x 22 columns]

# %%
merged_dataframe = India_final1.merge(India_df2, how='inner', left_on=['Country Name'], right_on=['Country'])
print(merged_dataframe)
# Out:
#    Country Name Country Code  \
# 0         India          IND
# 1         India          IND
# 2         India          IND
# 3         India          IND
# 4         India          IND
# ..          ...          ...
# 80        India          IND
# 81        India          IND
# 82        India          IND
# 83        India          IND
# 84        India          IND
#
#                                           Series Name        Series Code  \
# 0   Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# 1                              Broad money (% of GDP)  FM.LBL.BMNY.GD.ZS
# 2           Central government debt, total (% of GDP)  GC.DOD.TOTL.GD.ZS
# 3          Claims on central government, etc. (% GDP)  FS.AST.CGOV.GD.ZS
# 4   Claims on other sectors of the domestic econom...  FS.AST.DOMO.GD.ZS
# ..                                                ...                ...
# 80                             Tax revenue (% of GDP)  GC.TAX.TOTL.GD.ZS
# ...

# %%
merged_dataframe.head(3)
# Out:
#   Country Name Country Code  \
# 0        India          IND
# 1        India          IND
# 2        India          IND
#
#                                          Series Name        Series Code  \
# 0  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# 1                             Broad money (% of GDP)  FM.LBL.BMNY.GD.ZS
# 2          Central government debt, total (% of GDP)  GC.DOD.TOTL.GD.ZS
#
#   1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# 0   41.31283906   40.38740161    38.3713352   39.31975131   41.18773833
# 1   22.07192494   21.50187279   21.93070271   21.11628266    19.8063983
# 2            ..            ..            ..            ..            ..
#
#   1965 [YR1965]  ...      20-39      40-59        60+ 0-4(%) 5-9(%) 10-14(%)  \
# 0   38.95214348  ...   455,538    297,792    139,610    8.5%   8.5%     9.1%
# 1    20.8286159  ...   455,538    297,792    139,610    8.5%   8.5%     9.1%
# ...

# %%
merged_dataframe.to_csv('C:/Users/Desktop/Challenge/WBI/merged_dataframe.csv', encoding='windows-1252')
