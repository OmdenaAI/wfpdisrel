# %%
# !pip install wikipedia
# Out:
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-cp36-none-any.whl size=11686 sha256=9a54c80502990febc895863033df4461bf92a595b7cf9737d9a3ed8aa7fd6b7c
#   Stored in directory: /root/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# ...

# %%
import re
import wikipedia
from bs4 import BeautifulSoup
import urllib.request

# %%
cyclone_list = ["Hurricane_Jane",
"Typhoon_Iris_(1951)",
"Hurricane_Charlie_(1951)",
"Typhoon_Ruth_(1951)",
"Typhoon_Wanda_(1951)",
"Typhoon_Amy_(1951)",
"Typhoon_Emma_(1952)",
"Typhoon_Trix_(1952)",
"Typhoon_Wilma_(1952)",
"Hurricane_Carol_(1954)",
"Hurricane_Hazel",
"Hurricane_Diane",
"Hurricane_Hilda_(1955)",
"Hurricane_Janet_(1955)",
"Hurricane_Audrey_(1957)",
"Typhoon_Ida_(1958)",
"Typhoon_Iris_(1959)",
"Typhoon_Sarah_(1959)",
"Typhoon_Vera_(1959)",
"Typhoon_Karen_(1960)",
"Tropical_Storm_Lucille_(1960)",
"Tropical_Storm_Lucille_(1960)",
"Typhoon_Olive_(1960)",
"Hurricane_Donna_(1960)",
"Tropical_Storm_Kit",
"Typhoon_Lola_(1960)",
"Hurricane_Carla_(1961)",
"Hurricane_Hattie_(1961)",
"Hurricane_Tara_(1961)",
"Typhoon_Damrey",
"Typhoon_Rena_(1949)"
               
]

# %%
regexLetters = u'[A-Za-z]+'
regexHomeless = u'^homeless.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexHomeless, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*homeless.*'))
    print(findHomeless(sent))
# Out:
# ('Hurricane_Jane', None, 0)
# ('Typhoon_Iris_(1951)', None, 0)
# ('Hurricane_Charlie_(1951)', None, 0)
# ('Typhoon_Ruth_(1951)', None, 0)
# ('Typhoon_Wanda_(1951)', None, 0)
# ('Typhoon_Amy_(1951)', None, 0)
# ('Typhoon_Emma_(1952)', None, 0)
# ('Typhoon_Trix_(1952)', None, 0)
# ('Typhoon_Wilma_(1952)', None, 0)
# ('Hurricane_Carol_(1954)', None, 0)
# ('Hurricane_Hazel', '4,000', 4)
# ('Hurricane_Diane', None, 22)
# ('Hurricane_Hilda_(1955)', '15,000', 1)
# ('Hurricane_Janet_(1955)', '20,000', 3)
# ('Hurricane_Audrey_(1957)', None, 0)
# ('Typhoon_Ida_(1958)', None, 0)
# ('Typhoon_Iris_(1959)', '10,000', 1)
# ('Typhoon_Sarah_(1959)', '782,126', 2)
# ('Typhoon_Vera_(1959)', '1.5', 3)
# ('Typhoon_Karen_(1960)', '7,000', 1)
# ('Tropical_Storm_Lucille_(1960)', None, 0)
# ('Tropical_Storm_Lucille_(1960)', None, 0)
# ('Typhoon_Olive_(1960)', '7,000', 1)
# ('Hurricane_Donna_(1960)', None, 0)
# ('Tropical_Storm_Kit', None, 0)
# ('Typhoon_Lola_(1960)', '7,000', 1)
# ...

# %%
regexLetters = u'[A-Za-z]+'
regexAffected = u'^affected.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexAffected, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*affected.*'))
    print(findHomeless(sent))
# Out:
# ('Hurricane_Jane', None, 0)
# ('Typhoon_Iris_(1951)', None, 0)
# ('Hurricane_Charlie_(1951)', None, 0)
# ('Typhoon_Ruth_(1951)', None, 0)
# ('Typhoon_Wanda_(1951)', None, 0)
# ('Typhoon_Amy_(1951)', None, 0)
# ('Typhoon_Emma_(1952)', None, 0)
# ('Typhoon_Trix_(1952)', None, 0)
# ('Typhoon_Wilma_(1952)', None, 0)
# ('Hurricane_Carol_(1954)', None, 0)
# ('Hurricane_Hazel', ',', 14)
# ('Hurricane_Diane', '.', 2)
# ('Hurricane_Hilda_(1955)', '11,432', 4)
# ('Hurricane_Janet_(1955)', None, 10)
# ('Hurricane_Audrey_(1957)', None, 0)
# ('Typhoon_Ida_(1958)', None, 0)
# ('Typhoon_Iris_(1959)', None, 0)
# ('Typhoon_Sarah_(1959)', None, 0)
# ('Typhoon_Vera_(1959)', None, 0)
# ('Typhoon_Karen_(1960)', None, 0)
# ('Tropical_Storm_Lucille_(1960)', None, 0)
# ('Tropical_Storm_Lucille_(1960)', None, 0)
# ('Typhoon_Olive_(1960)', None, 0)
# ('Hurricane_Donna_(1960)', '(278', 12)
# ('Tropical_Storm_Kit', None, 0)
# ('Typhoon_Lola_(1960)', None, 0)
# ('Hurricane_Carla_(1961)', None, 0)
# ...

# %%
for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*homeless.*'))
    for sentence in sent:
        print(cyclone)
        print(sentence)
        print()
# Out:
# Hurricane_Hazel
# The death toll of 81 people has not since been equaled by a natural disaster in Canada. In addition to the casualties, over 4,000 families were left homeless.
#
# Hurricane_Diane
#  Helicopters assisted in discovering bodies at Camp Davis, where many deaths occurred during the storm. Statewide, thousands of people were left homeless.
#
# Hurricane_Hilda_(1955)
# . Hilda struck the city early on September 19, with gusts estimated at 150 mph (240 km/h). It dropped heavy rainfall that flooded 90% of Tampico, while its strong winds damaged half of the homes, leaving 15,000 homeless. The storm killed 300 people and caused over $120 million (1955
#
# Hurricane_Janet_(1955)
# ...

# %%
cyclone_list = ["Tropical_Storm_Harriet_(1962)",
"Typhoon_Carmen_(1963)",
"Hurricane_Flora",
"Typhoon_Winnie_(1964)",
"Hurricane_Cleo_(1964)",
"Cyclone_Dora_(1964)",
"Typhoon_Ruby_(1964)",
"Typhoon_Iris_(1964)",
"Typhoon_Dinah_(1965)",
"Typhoon_Mary_(1965)",
"Hurricane_Betsy_(1965)",
"Typhoon_Shirley_(1965)",
"Typhoon_Judy",
"Cyclone_Angela_(1966)",
"Typhoon_Billie_(1967)",
"Hurricane_Katrina_(1967)",
"Hurricane_Beulah_(1967)",
"Hurricane_Fern_(1967)",
"Typhoon_Emma_(1967)",
"Hurricane_Georgette",
"Typhoon_Shirley_(1968)",
"Hurricane_Gladys_(1968)",
"Typhoon_Mamie_(1968)",
"Typhoon_Nina_(1968)",
"Typhoon_Ora_(1968)",
"Tropical_Storm_Becky",
"Hurricane_Camille_(1969)",
"Hurricane_Francelia_(1969)",
"Cyclone_Ada_(1970)",
"Hurricane_Jane",
"Hurricane_Celia_(1970)"
               
]

# %%
regexLetters = u'[A-Za-z]+'
regexHomeless = u'^homeless.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexHomeless, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*homeless.*'))
    print(findHomeless(sent))
# Out:
# ('Tropical_Storm_Harriet_(1962)', '5,000', 3)
# ('Typhoon_Carmen_(1963)', None, 0)
# ('Hurricane_Flora', None, 0)
# ('Typhoon_Winnie_(1964)', None, 42)
# ('Hurricane_Cleo_(1964)', None, 0)
# ('Cyclone_Dora_(1964)', None, 0)
# ('Typhoon_Ruby_(1964)', None, 42)
# ('Typhoon_Iris_(1964)', None, 42)
# ('Typhoon_Dinah_(1965)', None, 0)
# ('Typhoon_Mary_(1965)', None, 0)
# ('Hurricane_Betsy_(1965)', None, 0)
# ('Typhoon_Shirley_(1965)', None, 0)
# ('Typhoon_Judy', '40,000', 2)
# ('Cyclone_Angela_(1966)', None, 0)
# ('Typhoon_Billie_(1967)', None, 0)
# ('Hurricane_Katrina_(1967)', '2,500', 1)
# ('Hurricane_Beulah_(1967)', None, 0)
# ('Hurricane_Fern_(1967)', '100,000', 2)
# ('Typhoon_Emma_(1967)', None, 0)
# ('Hurricane_Georgette', None, 0)
# ('Typhoon_Shirley_(1968)', None, 0)
# ('Hurricane_Gladys_(1968)', None, 0)
# ('Typhoon_Mamie_(1968)', None, 0)
# ('Typhoon_Nina_(1968)', None, 0)
# ('Typhoon_Ora_(1968)', None, 0)
# ('Tropical_Storm_Becky', None, 0)
# ...

# %%
regexLetters = u'[A-Za-z]+'
regexAffected = u'^affected.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexAffected, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*affected.*'))
    print(findHomeless(sent))
# Out:
# ('Tropical_Storm_Harriet_(1962)', '8,', 1)
# ('Typhoon_Carmen_(1963)', None, 0)
# ('Hurricane_Flora', None, 0)
# ('Typhoon_Winnie_(1964)', None, 53)
# ('Hurricane_Cleo_(1964)', None, 0)
# ('Cyclone_Dora_(1964)', None, 0)
# ('Typhoon_Ruby_(1964)', None, 53)
# ('Typhoon_Iris_(1964)', None, 53)
# ('Typhoon_Dinah_(1965)', None, 0)
# ('Typhoon_Mary_(1965)', None, 0)
# ('Hurricane_Betsy_(1965)', None, 0)
# ('Typhoon_Shirley_(1965)', None, 0)
# ('Typhoon_Judy', '(5.6', 6)
# ('Cyclone_Angela_(1966)', None, 0)
# ('Typhoon_Billie_(1967)', None, 0)
# ('Hurricane_Katrina_(1967)', '(80', 21)
# ('Hurricane_Beulah_(1967)', None, 0)
# ('Hurricane_Fern_(1967)', None, 0)
# ('Typhoon_Emma_(1967)', None, 0)
# ('Hurricane_Georgette', None, 0)
# ('Typhoon_Shirley_(1968)', None, 0)
# ('Hurricane_Gladys_(1968)', None, 0)
# ('Typhoon_Mamie_(1968)', None, 0)
# ('Typhoon_Nina_(1968)', None, 0)
# ('Typhoon_Ora_(1968)', None, 0)
# ('Tropical_Storm_Becky', None, 0)
# ('Hurricane_Camille_(1969)', '3,765', 3)
# ...

# %%
for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*affected.*'))
    for sentence in sent:
        print(cyclone)
        print(sentence)
        print()
# Out:
# Tropical_Storm_Harriet_(1962)
#  on September 7, weakening over land. After crossing out into open waters, the remains of Amy became extratropical on September 8, affected by the cold air.
#
# Typhoon_Winnie_(1964)
#  The entire city suffered a blackout from Winnie, and officials reported that it would take days to begin restoring power. High winds downed large billboards and tore roofs off many structures as well as uprooting trees. Thousands of residents were left homeless by the storm. Torrential rains triggered widespread flooding throughout the affected region, isolating several communities. Sea and airports were closed for several days due to the system.
#
# Typhoon_Ruby_(1964)
# ...

# %%
cyclone_list = ["Typhoon_Georgia_(1970)",
"Typhoon_Joan_(1970)",
"Typhoon_Kate_(1970)",
"Typhoon_Patsy_(1970)",
"Typhoon_Wanda_(1971)",
"Typhoon_Dinah",
"Typhoon_Elaine_(1971)",
"Cyclone_Althea_(1971)",
"Typhoon_Kit_(1972)",
"Hurricane_Hannah",
"Typhoon_Agnes",
"Typhoon_Ora_(1972)",
"Typhoon_Helen_(1972)",
"Hurricane_Bebe",
"Typhoon_Nora_(1973)",
"Typhoon_Ruth_(1973)",
"Tropical_Storm_Vera_(1973)",
"Cyclone_Wanda_(1974)",
"Typhoon_Dinah_(1974)",
"Tropical_Storm_Alma_(1974)",
"Typhoon_Bess_(1974)",
"Typhoon_Carmen_(1974)",
"Hurricane_Elaine",
"Typhoon_Irma_(1974)",
"Typhoon_Tracy",
"Hurricane_Val",
"Typhoon_Gervaise",
"Cyclone_Alison_(1975)",
"Typhoon_Phyllis_(1975)",
"Hurricane_Eloise_(1975)",
"Hurricane_Olivia_(1975)"
               
]

# %%
regexLetters = u'[A-Za-z]+'
regexHomeless = u'^homeless.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexHomeless, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*homeless.*'))
    print(findHomeless(sent))
# Out:
# ('Typhoon_Georgia_(1970)', '5,000', 2)
# ('Typhoon_Joan_(1970)', '80,000', 2)
# ('Typhoon_Kate_(1970)', None, 0)
# ('Typhoon_Patsy_(1970)', None, 0)
# ('Typhoon_Wanda_(1971)', '5,600', 2)
# ('Typhoon_Dinah', None, 0)
# ('Typhoon_Elaine_(1971)', '5,600', 2)
# ('Cyclone_Althea_(1971)', None, 0)
# ('Typhoon_Kit_(1972)', '385', 3)
# ('Hurricane_Hannah', None, 0)
# ('Typhoon_Agnes', None, 0)
# ('Typhoon_Ora_(1972)', None, 0)
# ('Typhoon_Helen_(1972)', None, 0)
# ('Hurricane_Bebe', None, 0)
# ('Typhoon_Nora_(1973)', '1', 5)
# ('Typhoon_Ruth_(1973)', None, 0)
# ('Tropical_Storm_Vera_(1973)', None, 0)
# ('Cyclone_Wanda_(1974)', '8000', 3)
# ('Typhoon_Dinah_(1974)', None, 0)
# ('Tropical_Storm_Alma_(1974)', '500', 2)
# ('Typhoon_Bess_(1974)', None, 0)
# ('Typhoon_Carmen_(1974)', None, 0)
# ('Hurricane_Elaine', '150,000', 4)
# ('Typhoon_Irma_(1974)', None, 0)
# ('Typhoon_Tracy', None, 0)
# ('Hurricane_Val', None, 0)
# ('Typhoon_Gervaise', '25%', 16)
# ('Cyclone_Alison_(1975)', None, 0)
# ...

# %%
regexLetters = u'[A-Za-z]+'
regexAffected = u'^affected.*'

def findHomeless(sent):
    lastDigit = None
    distance = 0
    for sentence in sent:
        sentence = sentence.replace(u'\xa0', u' ')
        words = sentence.split(" ")
        for word in words:
            if len(word)>0:
                distance += 1
                if not bool(re.search(regexLetters, word)):
                    lastDigit = word
                    distance = 0
                if bool(re.search(regexAffected, word)):
                    return cyclone, lastDigit, distance
                
    return cyclone, lastDigit, distance

for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*affected.*'))
    print(findHomeless(sent))
# Out:
# ('Typhoon_Georgia_(1970)', None, 0)
# ('Typhoon_Joan_(1970)', None, 0)
# ('Typhoon_Kate_(1970)', '24', 6)
# ('Typhoon_Patsy_(1970)', None, 0)
# ('Typhoon_Wanda_(1971)', '1971', 9)
# ('Typhoon_Dinah', None, 0)
# ('Typhoon_Elaine_(1971)', '1971', 9)
# ('Cyclone_Althea_(1971)', None, 0)
# ('Typhoon_Kit_(1972)', '4', 13)
# ('Hurricane_Hannah', None, 0)
# ('Typhoon_Agnes', None, 0)
# ('Typhoon_Ora_(1972)', None, 0)
# ('Typhoon_Helen_(1972)', None, 0)
# ('Hurricane_Bebe', None, 0)
# ('Typhoon_Nora_(1973)', None, 0)
# ('Typhoon_Ruth_(1973)', '20.', 4)
# ('Tropical_Storm_Vera_(1973)', '20.', 4)
# ('Cyclone_Wanda_(1974)', None, 0)
# ('Typhoon_Dinah_(1974)', None, 0)
# ('Tropical_Storm_Alma_(1974)', '1963.', 10)
# ('Typhoon_Bess_(1974)', None, 0)
# ('Typhoon_Carmen_(1974)', None, 0)
# ('Hurricane_Elaine', None, 0)
# ('Typhoon_Irma_(1974)', None, 0)
# ('Typhoon_Tracy', None, 0)
# ('Hurricane_Val', None, 0)
# ('Typhoon_Gervaise', None, 3)
# ('Cyclone_Alison_(1975)', None, 0)
# ...

# %%
for cyclone in cyclone_list:
    url = url = "https://en.wikipedia.org/wiki/" + cyclone
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page, "lxml")
    sent = soup.find_all(text=re.compile('\.[0-9]?.*affected.*'))
    for sentence in sent:
        print(cyclone)
        print(sentence)
        print()
# Out:
# Typhoon_Kate_(1970)
#  as most tactical bombing missions were canceled. During the 24 hours in which the storm affected Vietnam, the United States launched 46 air bombings, the fewest in over two years.
#
# Typhoon_Wanda_(1971)
# This is a table of all of the storms that have formed in the 1971 Pacific TY season. It includes their duration, names, affected areas, damages, and death totals. Deaths in parentheses are additional and indirect (an example of an indirect death would be a traffic accident), but were still related to that storm. Damage and deaths include totals while the storm was extratropical, a wave, or a low, and all of the damage figures are in 1971 USD. Names listed in parentheses were assigned by PAGASA.
#
#
# Typhoon_Elaine_(1971)
# ...
